# %% [markdown]
# # UIDAI Biometric Data Analysis file 1

# %%
#importing necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1 = pd.read_csv('/content/api_data_aadhar_demographic_2000000_2071700.csv')

# %%
df1.head()
# Out:
#          date           state  district  pincode  demo_age_5_17  demo_age_17_
# 0  16-12-2025  Madhya Pradesh  Shajapur   465113              0             4
# 1  16-12-2025  Madhya Pradesh  Shajapur   465226              2            14
# 2  16-12-2025  Madhya Pradesh  Shajapur   465339              1             2
# 3  16-12-2025  Madhya Pradesh  Shajapur   465447              1            19
# 4  16-12-2025  Madhya Pradesh   Sheopur   476332             11            25

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71700 entries, 0 to 71699
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           71700 non-null  object
#  1   state          71700 non-null  object
#  2   district       71700 non-null  object
#  3   pincode        71700 non-null  int64
#  4   demo_age_5_17  71700 non-null  int64
#  5   demo_age_17_   71700 non-null  int64
# dtypes: int64(3), object(3)
# memory usage: 3.3+ MB

# %%
df1.describe()
# Out:
#              pincode  demo_age_5_17  demo_age_17_
# count   71700.000000   71700.000000  71700.000000
# mean   527997.486471       1.325690     12.352873
# std    194340.288150       2.389325     21.910108
# min    100000.000000       0.000000      0.000000
# 25%    401102.000000       0.000000      2.000000
# 50%    522005.500000       0.000000      5.000000
# 75%    700052.000000       2.000000     14.000000
# max    855456.000000      52.000000   1608.000000

# %%
df1.shape
# Out:
# (71700, 6)

# %%
df1.columns
# Out:
# Index(['date', 'state', 'district', 'pincode', 'demo_age_5_17',
#        'demo_age_17_'],
#       dtype='object')

# %%
df1.isnull().sum()
# Out:
# date             0
# state            0
# district         0
# pincode          0
# demo_age_5_17    0
# demo_age_17_     0
# dtype: int64

# %%
#duplicated data
df1[df1.duplicated()]
# Out:
# Empty DataFrame
# Columns: [date, state, district, pincode, demo_age_5_17, demo_age_17_]
# Index: []

# %%
# without duplicates data
df1 = df1[~df1.duplicated()]
df1.shape
# Out:
# (71700, 6)

# %%
# Making copy of data for cleaning
df = df1.copy()

# %%
df[~df.duplicated()]
# Out:
#              date           state        district  pincode  demo_age_5_17  \
# 0      16-12-2025  Madhya Pradesh        Shajapur   465113              0
# 1      16-12-2025  Madhya Pradesh        Shajapur   465226              2
# 2      16-12-2025  Madhya Pradesh        Shajapur   465339              1
# 3      16-12-2025  Madhya Pradesh        Shajapur   465447              1
# 4      16-12-2025  Madhya Pradesh         Sheopur   476332             11
# ...           ...             ...             ...      ...            ...
# 71695  29-12-2025     West Bengal  West Midnapore   721212              0
# 71696  29-12-2025     West Bengal  West Midnapore   721420              0
# 71697  29-12-2025     West Bengal  West Midnapore   721424              0
# 71698  29-12-2025     West Bengal  West Midnapore   721426              0
# 71699  29-12-2025     West Bengal         hooghly   712701              0
#
#        demo_age_17_
# 0                 4
# 1                14
# 2                 2
# 3                19
# 4                25
# ...             ...
# 71695            12
# 71696             1
# 71697             5
# 71698             3
# 71699             1
#
# [71700 rows x 6 columns]

# %%
# removing duplicates
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (71700, 6)

# %%
df.head()
# Out:
#          date           state  district  pincode  demo_age_5_17  demo_age_17_
# 0  16-12-2025  Madhya Pradesh  Shajapur   465113              0             4
# 1  16-12-2025  Madhya Pradesh  Shajapur   465226              2            14
# 2  16-12-2025  Madhya Pradesh  Shajapur   465339              1             2
# 3  16-12-2025  Madhya Pradesh  Shajapur   465447              1            19
# 4  16-12-2025  Madhya Pradesh   Sheopur   476332             11            25

# %%
# First Feature Cleaning
df['state'].unique()
# Out:
# array(['Madhya Pradesh', 'Maharashtra', 'Uttar Pradesh', 'Uttarakhand',
#        'West Bangal', 'West Bengal', 'Manipur', 'Meghalaya', 'Mizoram',
#        'Nagaland', 'Odisha', 'Orissa', 'Pondicherry', 'Puducherry',
#        'Punjab', 'Rajasthan', 'Andhra Pradesh', 'Arunachal Pradesh',
#        'Assam', 'Bihar', 'West bengal', 'andhra pradesh', 'west Bengal',
#        'Chandigarh', 'Chhattisgarh', 'Dadra and Nagar Haveli',
#        'Dadra and Nagar Haveli and Daman and Diu', 'Delhi', 'Goa',
#        'Gujarat', 'Haryana', 'Himachal Pradesh', 'Jammu & Kashmir',
#        'Jammu and Kashmir', 'Jharkhand', 'Karnataka', 'Kerala',
#        'Tamil Nadu', 'Telangana', 'Tripura', 'Daman & Diu',
#        'Daman and Diu', 'Ladakh', 'Lakshadweep', 'Sikkim', 'Westbengal',
#        '100000', 'Andaman & Nicobar Islands',
#        'Andaman and Nicobar Islands', 'Dadra & Nagar Haveli', 'ODISHA',
#        'odisha', 'Nagpur', 'WESTBENGAL', 'WEST BENGAL',
#        'Raja Annamalai Puram', 'West  Bengal'], dtype=object)

# %%
df['state']=df['state'].str.strip().str.lower()

# %%
df['state'].unique()
# Out:
# array(['madhya pradesh', 'maharashtra', 'uttar pradesh', 'uttarakhand',
#        'west bangal', 'west bengal', 'manipur', 'meghalaya', 'mizoram',
#        'nagaland', 'odisha', 'orissa', 'pondicherry', 'puducherry',
#        'punjab', 'rajasthan', 'andhra pradesh', 'arunachal pradesh',
#        'assam', 'bihar', 'chandigarh', 'chhattisgarh',
#        'dadra and nagar haveli',
#        'dadra and nagar haveli and daman and diu', 'delhi', 'goa',
#        'gujarat', 'haryana', 'himachal pradesh', 'jammu & kashmir',
#        'jammu and kashmir', 'jharkhand', 'karnataka', 'kerala',
#        'tamil nadu', 'telangana', 'tripura', 'daman & diu',
#        'daman and diu', 'ladakh', 'lakshadweep', 'sikkim', 'westbengal',
#        '100000', 'andaman & nicobar islands',
#        'andaman and nicobar islands', 'dadra & nagar haveli', 'nagpur',
#        'raja annamalai puram', 'west  bengal'], dtype=object)

# %%
df[df['state'].str.contains("&")]['state'].str.replace("&", "and")
# Out:
# 3198               jammu and kashmir
# 5219                   daman and diu
# 7371     andaman and nicobar islands
# 8179          dadra and nagar haveli
# 8180                   daman and diu
# 8181                   daman and diu
# 10641              jammu and kashmir
# 11291    andaman and nicobar islands
# 11292    andaman and nicobar islands
# 11675    andaman and nicobar islands
# 12445                  daman and diu
# 12844              jammu and kashmir
# 17220    andaman and nicobar islands
# 19241                  daman and diu
# 19648              jammu and kashmir
# 22654                  daman and diu
# 22655                  daman and diu
# 25316    andaman and nicobar islands
# 25317    andaman and nicobar islands
# 25318    andaman and nicobar islands
# 25319    andaman and nicobar islands
# 30884    andaman and nicobar islands
# 30885    andaman and nicobar islands
# 37474    andaman and nicobar islands
# 37789    andaman and nicobar islands
# 37790    andaman and nicobar islands
# 38276              jammu and kashmir
# 38277              jammu and kashmir
# 39840                  daman and diu
# 40416    andaman and nicobar islands
# 40417    andaman and nicobar islands
# 40418    andaman and nicobar islands
# 46999    andaman and nicobar islands
# 47000    andaman and nicobar islands
# 48231              jammu and kashmir
# 53237              jammu and kashmir
# 54787         dadra and nagar haveli
# 54789                  daman and diu
# 54790                  daman and diu
# 55206              jammu and kashmir
# 59381    andaman and nicobar islands
# 59938                  daman and diu
# 60949    andaman and nicobar islands
# 66340         dadra and nagar haveli
# 69725    andaman and nicobar islands
# Name: state, dtype: object

# %%
df['state']=df['state'].str.replace("&", "and")

# %%
df[df['state'].str.startswith("o")]['state'].unique()
# Out:
# array(['odisha', 'orissa'], dtype=object)

# %%
df['state']=df['state'].str.replace('orissa','odisha')
df['state'] = df['state'].str.replace('chhatisgarh', 'chhattisgarh')
df['state'] = df['state'].str.replace('west bengli', 'west bengal')

# %%
df['state'].unique()
# Out:
# array(['madhya pradesh', 'maharashtra', 'uttar pradesh', 'uttarakhand',
#        'west bangal', 'west bengal', 'manipur', 'meghalaya', 'mizoram',
#        'nagaland', 'odisha', 'pondicherry', 'puducherry', 'punjab',
#        'rajasthan', 'andhra pradesh', 'arunachal pradesh', 'assam',
#        'bihar', 'chandigarh', 'chhattisgarh', 'dadra and nagar haveli',
#        'dadra and nagar haveli and daman and diu', 'delhi', 'goa',
#        'gujarat', 'haryana', 'himachal pradesh', 'jammu and kashmir',
#        'jharkhand', 'karnataka', 'kerala', 'tamil nadu', 'telangana',
#        'tripura', 'daman and diu', 'ladakh', 'lakshadweep', 'sikkim',
#        'westbengal', '100000', 'andaman and nicobar islands', 'nagpur',
#        'raja annamalai puram', 'west  bengal'], dtype=object)

# %%
df['state'] = df['state'].replace({
    'daman and diu': 'dadra and nagar haveli and daman and diu',
    'dadra and nagar haveli': 'dadra and nagar haveli and daman and diu',

})

# %%
df['state']=df['state'].str.replace(
    r'^\s*west\s*b[aeo]ngal\s*$',
    'west bengal',
    regex=True
)

# %%
df['state']=df['state'].replace({'pondicherry':'puducherry', 'uttaranchal':'uttarakhand'})

# %%
df[df['state']=='darbhanga']
# Out:
# Empty DataFrame
# Columns: [date, state, district, pincode, demo_age_5_17, demo_age_17_]
# Index: []

# %%
df[df['state']=='puttenahalli']
# Out:
# Empty DataFrame
# Columns: [date, state, district, pincode, demo_age_5_17, demo_age_17_]
# Index: []

# %%
df['state'].unique()
# Out:
# array(['madhya pradesh', 'maharashtra', 'uttar pradesh', 'uttarakhand',
#        'west bengal', 'manipur', 'meghalaya', 'mizoram', 'nagaland',
#        'odisha', 'puducherry', 'punjab', 'rajasthan', 'andhra pradesh',
#        'arunachal pradesh', 'assam', 'bihar', 'chandigarh',
#        'chhattisgarh', 'dadra and nagar haveli and daman and diu',
#        'delhi', 'goa', 'gujarat', 'haryana', 'himachal pradesh',
#        'jammu and kashmir', 'jharkhand', 'karnataka', 'kerala',
#        'tamil nadu', 'telangana', 'tripura', 'ladakh', 'lakshadweep',
#        'sikkim', '100000', 'andaman and nicobar islands', 'nagpur',
#        'raja annamalai puram'], dtype=object)

# %% [markdown]
# # State Feature Cleaned

# %% [markdown]
# ## Moving to next Feature (District)

# %%
df.shape
# Out:
# (71700, 6)

# %%
df['district'] = (
    df['district']
    .str.lower()
    .str.strip()
    .str.replace(r'\s+', ' ', regex=True)
)

# %%
df['district'].nunique()
# Out:
# 914

# %% [markdown]
# # It has various Unique values, so applying other logic

# %%
df['district'].unique()
# Out:
# array(['shajapur', 'sheopur', 'shivpuri', 'singrauli', 'tikamgarh',
#        'ujjain', 'umaria', 'vidisha', 'west nimar', 'ahilyanagar',
#        'ahmadnagar', 'ahmed nagar', 'akola', 'amravati', 'aurangabad',
#        'beed', 'bhandara', 'bid', 'buldana', 'buldhana', 'chandrapur',
#        'chatrapati sambhaji nagar', 'chhatrapati sambhajinagar',
#        'dharashiv', 'dhule', 'gadchiroli', 'gondia', 'gondiya *',
#        'hingoli', 'jalgaon', 'bara banki', 'bareilly', 'basti', 'bhadohi',
#        'bijnor', 'budaun', 'bulandshahar', 'bulandshahr', 'chandauli',
#        'chitrakoot', 'deoria', 'etah', 'etawah', 'faizabad',
#        'farrukhabad', 'fatehpur', 'firozabad', 'gautam buddha nagar',
#        'ghaziabad', 'ghazipur', 'gonda', 'gorakhpur', 'hamirpur', 'hapur',
#        'hardoi', 'hathras', 'jalaun', 'jaunpur', 'jhansi',
#        'jyotiba phule nagar', 'kannauj', 'kanpur dehat', 'kanpur nagar',
#        'kasganj', 'kaushambi', 'kheri', 'kushinagar', 'lalitpur',
#        'lucknow', 'maharajganj', 'mahoba', 'mainpuri', 'mathura', 'mau',
#        'meerut', 'mirzapur', 'moradabad', 'muzaffarnagar', 'pilibhit',
#        'pratapgarh', 'prayagraj', 'rae bareli', 'rampur', 'saharanpur',
#        'sambhal', 'sant kabir nagar', 'sant ravidas nagar',
#        'sant ravidas nagar bhadohi', 'shahjahanpur', 'shamli',
#        'shrawasti', 'siddharthnagar', 'sitapur', 'sonbhadra', 'sultanpur',
#        'unnao', 'varanasi', 'almora', 'bageshwar', 'chamoli', 'dehradun',
#        'garhwal', 'hardwar', 'haridwar', 'nainital', 'pauri garhwal',
#        'pithoragarh', 'tehri garhwal', 'udham singh nagar', 'howrah',
#        'alipurduar', 'bankura', 'barddhaman', 'bardhaman', 'birbhum',
#        'cooch behar', 'dakshin dinajpur', 'darjeeling', 'darjiling',
#        'east midnapore', 'haora', 'hooghly', 'hugli', 'jalpaiguri',
#        'jhargram', 'kalimpong', 'koch bihar', 'kolkata', 'malda',
#        'maldah', 'medinipur', 'murshidabad', 'nadia', 'north 24 parganas',
#        'north dinajpur', 'north twenty four parganas',
#        'paschim bardhaman', 'paschim medinipur', 'purba bardhaman',
#        'purba medinipur', 'purulia', 'puruliya', 'south 24 parganas',
#        'south dinajpur', 'south twenty four parganas', 'uttar dinajpur',
#        'west midnapore', 'jalna', 'kolhapur', 'latur', 'mumbai',
#        'mumbai city', 'mumbai suburban', 'mumbai( sub urban )', 'nagpur',
#        'nanded', 'nandurbar', 'nashik', 'osmanabad', 'palghar',
#        'parbhani', 'pune', 'raigad', 'raigarh', 'ratnagiri', 'sangli',
#        'satara', 'sindhudurg', 'solapur', 'thane', 'wardha', 'washim',
#        'yavatmal', 'bishnupur', 'churachandpur', 'imphal east',
#        'imphal west', 'jiribam', 'senapati', 'thoubal', 'ukhrul',
#        'east garo hills', 'east khasi hills', 'north garo hills',
#        'south garo hills', 'south west garo hills', 'aizawl', 'champhai',
#        'kolasib', 'lawngtlai', 'mammit', 'saiha', 'dimapur', 'kohima',
#        'longleng', 'peren', 'phek', 'angul', 'balangir', 'baleshwar',
#        'baleswar', 'bargarh', 'baudh', 'bhadrak', 'boudh', 'cuttack',
#        'dhenkanal', 'gajapati', 'ganjam', 'jajpur', 'jagatsinghapur',
#        'jagatsinghpur', 'jajapur', 'jharsuguda', 'kalahandi', 'kandhamal',
#        'kendrapara', 'kendujhar', 'khorda', 'khordha', 'koraput',
#        'malkangiri', 'mayurbhanj', 'nuapada', 'nabarangapur', 'nayagarh',
#        'puri', 'rayagada', 'sambalpur', 'sonapur', 'subarnapur',
#        'sundargarh', 'sundergarh', 'anugul', 'karaikal', 'pondicherry',
#        'puducherry', 'amritsar', 'barnala', 'bathinda', 'faridkot',
#        'fatehgarh sahib', 'fazilka', 'ferozepur', 'firozpur', 'gurdaspur',
#        'hoshiarpur', 'jalandhar', 'kapurthala', 'ludhiana', 'malerkotla',
#        'mansa', 'moga', 'nawanshahr', 'pathankot', 'patiala', 'rupnagar',
#        's.a.s nagar(mohali)', 'sas nagar (mohali)', 'sangrur',
#        'shaheed bhagat singh nagar', 'sri muktsar sahib', 'tarn taran',
#        'ajmer', 'alwar', 'banswara', 'baran', 'barmer', 'beawar',
#        'bharatpur', 'bhilwara', 'bikaner', 'bundi', 'chittaurgarh',
#        'chittorgarh', 'churu', 'dausa', 'dhaulpur', 'dholpur',
#        'didwana-kuchaman', 'dungarpur', 'ganganagar', 'hanumangarh',
#        'jaipur', 'adilabad', 'alluri sitharama raju', 'anantapur',
#        'ananthapur', 'ananthapuramu', 'annamayya', 'bapatla', 'chittoor',
#        'cuddapah', 'dr. b. r. ambedkar konaseema', 'east godavari',
#        'eluru', 'guntur', 'hyderabad', 'karimnagar', 'khammam', 'krishna',
#        'kurnool', 'mahabub nagar', 'medak', 'n. t. r', 'nalgonda',
#        'nellore', 'palnadu', 'prakasam', 'rangareddi',
#        'sri potti sriramulu nellore', 'sri sathya sai', 'srikakulam',
#        'tirupati', 'visakhapatnam', 'vizianagaram', 'warangal',
#        'west godavari', 'y. s. r', 'tirap', 'baksa', 'barpeta',
#        'biswanath', 'bongaigaon', 'cachar', 'charaideo', 'chirang',
#        'darrang', 'dhemaji', 'dhubri', 'dibrugarh', 'goalpara',
#        'golaghat', 'hailakandi', 'hojai', 'jorhat', 'kamrup',
#        'kamrup metro', 'karbi anglong', 'karimganj', 'kokrajhar',
#        'lakhimpur', 'marigaon', 'nagaon', 'nalbari', 'sibsagar',
#        'sonitpur', 'sribhumi', 'tinsukia', 'udalguri', 'araria', 'arwal',
#        'banka', 'begusarai', 'bhagalpur', 'bhojpur', 'buxar', 'darbhanga',
#        'east champaran', 'gaya', 'gopalganj', 'jamui', 'jehanabad',
#        'kaimur (bhabua)', 'katihar', 'khagaria', 'kishanganj',
#        'lakhisarai', 'madhepura', 'madhubani', 'munger', 'muzaffarpur',
#        'nalanda', 'nawada', 'patna', 'purba champaran', 'purnea',
#        'purnia', 'rohtas', 'saharsa', 'samastipur', 'saran', 'sheikhpura',
#        'sitamarhi', 'mahbubnagar', 'nandyal', 'nizamabad',
#        'parvathipuram manyam', 'changlang', 'kra daadi', 'kurung kumey',
#        'papum pare', 'shi-yomi', 'tawang', 'west kameng', 'majuli',
#        'tamulpur district', 'sheohar', 'siwan', 'supaul', 'vaishali',
#        'west champaran', 'chandigarh', 'balod', 'baloda bazar',
#        'balrampur', 'bastar', 'bemetara', 'bilaspur',
#        'dakshin bastar dantewada', 'dantewada', 'dhamtari', 'durg',
#        'gariyaband', 'janjgir-champa', 'jashpur', 'kabeerdham', 'kanker',
#        'khairagarh chhuikhadan gandai', 'kondagaon', 'korba', 'koriya',
#        'mahasamund', 'manendragarh–chirmiri–bharatpur',
#        'mohla-manpur-ambagarh chouki', 'mungeli', 'raipur', 'rajnandgaon',
#        'sakti', 'sarangarh-bilaigarh', 'sukma', 'surguja',
#        'uttar bastar kanker', 'dadra and nagar haveli', 'daman',
#        'central delhi', 'east delhi', 'new delhi', 'north delhi',
#        'north east', 'north east delhi', 'north west delhi',
#        'south delhi', 'south east delhi', 'south west delhi',
#        'west delhi', 'north goa', 'south goa', 'ahmadabad', 'ahmedabad',
#        'amreli', 'anand', 'arvalli', 'banaskantha', 'bharuch',
#        'bhavnagar', 'botad', 'chhotaudepur', 'dahod', 'devbhumi dwarka',
#        'dohad', 'gandhinagar', 'gir somnath', 'jamnagar', 'junagadh',
#        'kachchh', 'kheda', 'mahesana', 'mahisagar', 'morbi', 'narmada',
#        'navsari', 'panch mahals', 'panchmahals', 'patan', 'porbandar',
#        'rajkot', 'sabarkantha', 'surat', 'surendra nagar', 'tapi',
#        'vadodara', 'valsad', 'ambala', 'bhiwani', 'faridabad', 'gurgaon',
#        'hisar', 'jhajjar', 'jind', 'kaithal', 'karnal', 'mewat',
#        'surendranagar', 'charkhi dadri', 'fatehabad', 'kurukshetra',
#        'mahendragarh', 'palwal', 'panchkula', 'rewari', 'rohtak', 'sirsa',
#        'sonipat', 'yamuna nagar', 'yamunanagar', 'chamba', 'kangra',
#        'kinnaur', 'kullu', 'mandi', 'shimla', 'sirmaur', 'solan', 'una',
#        'baramula', 'anantnag', 'badgam', 'bandipore', 'budgam', 'doda',
#        'jammu', 'kargil', 'kathua', 'pulwama', 'punch', 'reasi',
#        'srinagar', 'udhampur', 'bokaro', 'chatra', 'deoghar', 'dhanbad',
#        'dumka', 'east singhbhum', 'garhwa', 'garhwa *', 'giridih',
#        'godda', 'gumla', 'hazaribag', 'hazaribagh', 'jamtara', 'khunti',
#        'kodarma', 'latehar', 'lohardaga', 'pakur', 'palamau', 'palamu',
#        'pashchimi singhbhum', 'purbi singhbhum', 'ramgarh', 'ranchi',
#        'sahebganj', 'sahibganj', 'seraikela-kharsawan', 'simdega',
#        'west singhbhum', 'bagalkot', 'bagalkot *', 'ballari', 'bangalore',
#        'bangalore rural', 'belagavi', 'belgaum', 'bellary', 'bengaluru',
#        'bengaluru south', 'bidar', 'bijapur', 'chamarajanagar',
#        'chamrajanagar', 'chickmagalur', 'chikkaballapur',
#        'chikkamagaluru', 'chikmagalur', 'chitradurga', 'dakshina kannada',
#        'davanagere', 'davangere', 'dharwad', 'gadag', 'gadag *',
#        'gulbarga', 'hasan', 'hassan', 'haveri', 'haveri *', 'kalaburagi',
#        'kodagu', 'kolar', 'koppal', 'mandya', 'mysore', 'mysuru',
#        'raichur', 'ramanagar', 'shimoga', 'shivamogga', 'tumakuru',
#        'tumkur', 'udupi', 'uttara kannada', 'vijayanagara', 'vijayapura',
#        'yadgir', 'alappuzha', 'ernakulam', 'idukki', 'kannur',
#        'kasaragod', 'kasargod', 'kollam', 'kottayam', 'kozhikode',
#        'salem', 'sivaganga', 'tenkasi', 'thanjavur', 'the nilgiris',
#        'theni', 'thiruvallur', 'thiruvarur', 'thoothukkudi',
#        'tiruchirappalli', 'tirunelveli', 'tirupattur', 'tiruppur',
#        'tiruvallur', 'tiruvannamalai', 'vellore', 'villupuram',
#        'viluppuram', 'virudhunagar', 'bhadradri kothagudem',
#        'hanumakonda', 'jagitial', 'jangoan', 'jayashankar bhupalpally',
#        'jogulamba gadwal', 'k.v. rangareddy', 'kamareddy',
#        'komaram bheem', 'mahabubabad', 'mahabubnagar', 'mancherial',
#        'medchal-malkajgiri', 'mulugu', 'nagarkurnool', 'narayanpet',
#        'peddapalli', 'rajanna sircilla', 'sangareddy', 'siddipet',
#        'suryapet', 'vikarabad', 'wanaparthy', 'warangal rural',
#        'warangal urban', 'yadadri.', 'khowai', 'north tripura',
#        'sepahijala', 'south tripura', 'unakoti', 'west tripura', 'agra',
#        'aligarh', 'allahabad', 'ambedkar nagar', 'amethi', 'amroha',
#        'auraiya', 'ayodhya', 'azamgarh', 'baghpat', 'bahraich', 'ballia',
#        'banda', 'barabanki', 'lower subansiri', 'bajali',
#        'north cachar hills', 'west karbi anglong',
#        'gaurela-pendra-marwahi', 'janjgir - champa',
#        'mohalla-manpur-ambagarh chowki', 'surajpur', 'diu', 'shahdara',
#        'banas kantha', 'malappuram', 'palakkad', 'pathanamthitta',
#        'thiruvananthapuram', 'thrissur', 'wayanad', 'lakshadweep',
#        'agar malwa', 'alirajpur', 'anuppur', 'ashok nagar', 'balaghat',
#        'barwani', 'betul', 'bhind', 'bhopal', 'burhanpur', 'chhatarpur',
#        'chhindwara', 'damoh', 'datia', 'dewas', 'dhar', 'dindori',
#        'east nimar', 'guna', 'gwalior', 'harda *', 'hoshangabad',
#        'indore', 'jabalpur', 'katni', 'khandwa', 'khargone', 'mandla',
#        'mauganj', 'morena', 'narmadapuram', 'narsimhapur', 'narsinghpur',
#        'neemuch', 'niwari', 'panna', 'raisen', 'rajgarh', 'ratlam',
#        'rewa', 'sagar', 'satna', 'sehore', 'seoni', 'shahdol', 'sidhi',
#        'gondiya', 'raigarh(mh)', 'washim *', 'kakching', 'tamenglong',
#        'eastern west khasi hills', 'ri bhoi', 'west garo hills',
#        'west jaintia hills', 'lunglei', 'serchhip', 'chumukedima',
#        'kiphire', 'mon', 'niuland', 'wokha', 'zunheboto', 'muktsar',
#        'balotra', 'deeg', 'jaisalmer', 'jalor', 'jalore', 'jhalawar',
#        'jhunjhunu', 'jhunjhunun', 'jodhpur', 'karauli',
#        'khairthal-tijara', 'kota', 'kotputli-behror', 'nagaur', 'pali',
#        'rajsamand', 'sawai madhopur', 'sikar', 'sirohi', 'tonk',
#        'udaipur', 'east', 'east sikkim', 'ariyalur', 'chengalpattu',
#        'chennai', 'coimbatore', 'cuddalore', 'dharmapuri', 'dindigul',
#        'erode', 'kallakurichi', 'kancheepuram', 'kanniyakumari',
#        'kanyakumari', 'karur', 'krishnagiri', 'madurai', 'mayiladuthurai',
#        'nagapattinam', 'namakkal', 'perambalur', 'pudukkottai',
#        'ramanathapuram', 'ranipet', 'champawat', 'rudraprayag',
#        'uttarkashi', 'hawrah', '100000', 'south andaman', 'anakapalli',
#        'k.v.rangareddy', 'kakinada', 'karim nagar', 'longding', 'namsai',
#        'siang', 'upper siang', 'west siang', 'kawardha', 'narayanpur',
#        'dadra & nagar haveli', 'sabar kantha', 'the dangs', 'panipat',
#        'harda', 'jhabua', 'maihar', 'mandsaur', 'pandhurna',
#        'nandurbar *', 'chandel', 'west khasi hills', 'mokokchung',
#        'noklak', 'tseminyu', 'mamit', 'debagarh', 'kishtwar', 'kupwara',
#        'rajouri', 'shupiyan', 'koderma', 'chamrajnagar', 'leh',
#        'andamans', 'north and middle andaman', 'pashchim champaran',
#        'samstipur', 'sheikpura', 'janjgir champa', 'bardez',
#        'lahul & spiti', 'ganderbal', 'ramban', 'samba', 'salumbar',
#        'north sikkim', 'south', 'west', 'west sikkim',
#        'medchal−malkajgiri', 'nirmal', 'east jaintia hills', 'rangareddy',
#        'dhalai', 'gomati', 'pherzawl', 'shamator', 'tuensang',
#        'east kameng', 'lohit', 'lower dibang valley', 'dima hasao',
#        'aurangabad(bh)', 'bhabua', 'najafgarh', 'lahul and spiti',
#        'jangaon', 'warangal (urban)', 'south salmara mankachar',
#        'monghyr', 'yanam', 'phalodi', 'north', 'south sikkim', 'kulgam',
#        'khawzawl', 'dibang valley', 'pakaur', 'saitual', 'tirupathur',
#        'near uday nagar nit garden', 'nicobar', 'bengaluru rural',
#        'lower siang', 'dhalai *', 'hooghiy', 'south west khasi hills',
#        'medchalâ\x88\x92malkajgiri', 'leparada', 'chamarajanagar *',
#        'kushinagar *', 'mahrajganj', 'bicholim', 'near dhyana ashram',
#        'upper subansiri', 'kangpokpi', 'kamle', 'mangan'], dtype=object)

# %%
df.shape
# Out:
# (71700, 6)

# %%
import pandas as pd
import json

# Step 1: Load your reference JSON file
with open('/content/state_district_reference.json', 'r', encoding='utf-8') as f:
    reference_data = json.load(f)


# Step 3: Create a simple validation function
def is_valid_district(state, district):
    """
    Check if district exists in the given state's district list

    Args:
        state (str): State name (must match JSON key exactly)
        district (str): District name to validate

    Returns:
        bool: True if district is in that state's list, False otherwise
    """
    # Get the districts list for this state from JSON
    if state in reference_data:
        valid_districts = reference_data[state]['districts']
        # Check if district is in the list
        return district in valid_districts
    return False

# Step 4: Apply validation to each row
df['is_valid'] = df.apply(
    lambda row: is_valid_district(row['state'], row['district']),
    axis=1
)

# Step 5: Get rows where matching didn't happen (invalid rows)
invalid_rows = df[df['is_valid'] == False]

# Step 6: Display results
print("=" * 70)
print("DISTRICT VALIDATION REPORT")
print("=" * 70)
print(f"\nTotal rows in dataset: {len(df)}")
print(f"Valid matches (district found in state's list): {df['is_valid'].sum()}")
print(f"INVALID/MISSPELLED rows (matching didn't happen): {len(invalid_rows)}")
print(f"Percentage of invalid rows: {(len(invalid_rows)/len(df)*100):.2f}%")
print("=" * 70)

# Step 7: Show sample of invalid records
if len(invalid_rows) > 0:
    print("\nSample of INVALID records (first 10):")
    print(invalid_rows[['state', 'district']].head(10).to_string(index=False))

    # Breakdown by state
    print("\n\nINVALID records breakdown by STATE:")
    print(invalid_rows['state'].value_counts().to_string())

# Step 8: Decide whether to drop based on count
print("\n" + "=" * 70)
if len(invalid_rows) >= 2000 and len(invalid_rows) <= 3000:
    print(f"✓ Invalid rows count: {len(invalid_rows)} (within 2k-3k range - SAFE TO DROP)")

    # Drop invalid rows and create cleaned dataset
    df_cleaned = df[df['is_valid'] == True].drop('is_valid', axis=1).reset_index(drop=True)

    print(f"✓ Original dataset shape: {df.shape}")
    print(f"✓ Cleaned dataset shape: {df_cleaned.shape}")
    print(f"✓ Rows dropped: {len(df) - len(df_cleaned)}")

    # Save cleaned data
    df_cleaned.to_csv('your_dataset_cleaned.csv', index=False)
    print(f"\n✓ Cleaned dataset saved to 'your_dataset_cleaned.csv'")

elif len(invalid_rows) < 2000:
    print(f"⚠ Invalid rows count: {len(invalid_rows)} (less than 2000)")
    print("  Suggestion: Consider fixing these records instead of dropping")

elif len(invalid_rows) > 3000:
    print(f"✗ Invalid rows count: {len(invalid_rows)} (more than 3000)")
    print("  Suggestion: Data quality issue - manual review needed before dropping")

# Step 9: Export invalid records for reference
if len(invalid_rows) > 0:
    invalid_rows[['state', 'district']].to_csv('invalid_records.csv', index=False)
    print(f"✓ Invalid records exported to 'invalid_records.csv' for review")

print("=" * 70)
# Out:
# ======================================================================
# DISTRICT VALIDATION REPORT
# ======================================================================
#
# Total rows in dataset: 71700
# Valid matches (district found in state's list): 57007
# INVALID/MISSPELLED rows (matching didn't happen): 14693
# Percentage of invalid rows: 20.49%
# ======================================================================
#
# Sample of INVALID records (first 10):
#          state   district
# madhya pradesh west nimar
#    maharashtra ahmadnagar
#    maharashtra ahmadnagar
#    maharashtra ahmadnagar
#    maharashtra ahmadnagar
#    maharashtra ahmadnagar
#    maharashtra ahmadnagar
#    maharashtra ahmadnagar
#    maharashtra ahmadnagar
#    maharashtra ahmadnagar
#
#
# INVALID records breakdown by STATE:
# state
# andhra pradesh                              3157
# karnataka                                   2081
# west bengal                                 1803
# maharashtra                                 1202
# odisha                                      1028
# tamil nadu                                   567
# telangana                                    567
# gujarat                                      553
# uttar pradesh                                400
# madhya pradesh                               334
# delhi                                        319
# bihar                                        286
# tripura                                      283
# manipur                                      265
# chhattisgarh                                 254
# assam                                        238
# punjab                                       225
# rajasthan                                    202
# jharkhand                                    167
# meghalaya                                    146
# haryana                                      130
# nagaland                                     127
# jammu and kashmir                            118
# sikkim                                        58
# puducherry                                    57
# uttarakhand                                   34
# kerala                                        34
# himachal pradesh                              18
# andaman and nicobar islands                   14
# mizoram                                       11
# arunachal pradesh                              6
# dadra and nagar haveli and daman and diu       3
# goa                                            3
# 100000                                         1
# nagpur                                         1
# raja annamalai puram                           1
#
# ======================================================================
# ✗ Invalid rows count: 14693 (more than 3000)
#   Suggestion: Data quality issue - manual review needed before dropping
# ✓ Invalid records exported to 'invalid_records.csv' for review
# ======================================================================

# %%
df.head()
# Out:
#          date           state  district  pincode  demo_age_5_17  demo_age_17_  \
# 0  16-12-2025  madhya pradesh  shajapur   465113              0             4
# 1  16-12-2025  madhya pradesh  shajapur   465226              2            14
# 2  16-12-2025  madhya pradesh  shajapur   465339              1             2
# 3  16-12-2025  madhya pradesh  shajapur   465447              1            19
# 4  16-12-2025  madhya pradesh   sheopur   476332             11            25
#
#    is_valid
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True

# %%
df_cleaned = df[df['is_valid'] == True].drop('is_valid', axis=1).reset_index(drop=True)

# %%
df_anomalies = df[df['is_valid']==False].drop('is_valid',axis=1).reset_index(drop=True)

# %%
df_cleaned.shape
# Out:
# (57007, 6)

# %%
df_cleaned.columns
# Out:
# Index(['date', 'state', 'district', 'pincode', 'demo_age_5_17',
#        'demo_age_17_'],
#       dtype='object')

# %%
df_cleaned['state'].unique()
# Out:
# array(['madhya pradesh', 'maharashtra', 'uttar pradesh', 'uttarakhand',
#        'west bengal', 'mizoram', 'odisha', 'puducherry', 'punjab',
#        'rajasthan', 'andhra pradesh', 'arunachal pradesh', 'assam',
#        'bihar', 'chandigarh', 'chhattisgarh',
#        'dadra and nagar haveli and daman and diu', 'delhi', 'goa',
#        'gujarat', 'haryana', 'himachal pradesh', 'jammu and kashmir',
#        'jharkhand', 'karnataka', 'kerala', 'tamil nadu', 'telangana',
#        'ladakh', 'lakshadweep', 'andaman and nicobar islands'],
#       dtype=object)

# %%
df_cleaned.to_csv("demo_cleaned_5.csv")

# %%
df_anomalies.shape
# Out:
# (14693, 6)

# %%
df_anomalies.to_csv('demo_anomalies_5.csv')
