# %% [markdown]
# # UIDAI Biometric Data Analysis file 1

# %%
#importing necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/demo_cleaned_final.csv')

# %%
df.shape
# Out:
# (1560734, 6)

# %%
df.head()
# Out:
#          date           state    district  pincode  demo_age_5_17  \
# 0  01-03-2025   uttar pradesh   gorakhpur   273213             49
# 1  01-03-2025  andhra pradesh    chittoor   517132             22
# 2  01-03-2025         gujarat      rajkot   360006             65
# 3  01-03-2025  andhra pradesh  srikakulam   532484             24
# 4  01-03-2025       rajasthan     udaipur   313801             45
#
#    demo_age_17_
# 0           529
# 1           375
# 2           765
# 3           314
# 4           785

# %%
df['district'] = df['district'].str.upper()
df['state'] = df['state'].str.upper()

# %%
df.head()
# Out:
#          date           state    district  pincode  demo_age_5_17  \
# 0  01-03-2025   UTTAR PRADESH   GORAKHPUR   273213             49
# 1  01-03-2025  ANDHRA PRADESH    CHITTOOR   517132             22
# 2  01-03-2025         GUJARAT      RAJKOT   360006             65
# 3  01-03-2025  ANDHRA PRADESH  SRIKAKULAM   532484             24
# 4  01-03-2025       RAJASTHAN     UDAIPUR   313801             45
#
#    demo_age_17_
# 0           529
# 1           375
# 2           765
# 3           314
# 4           785

# %%
import json
import pandas as pd

# Load the pincode reference JSON file
with open('pin-code-data.json', 'r') as f:
    pincode_reference = json.load(f)

# Convert pincode values to strings for consistent lookup
df['pincode_str'] = df['pincode'].astype(str)

# Use map with default None for missing values
df['state_new'] = df['pincode_str'].map(
    lambda x: pincode_reference.get(x, {}).get('state', None)
)
df['district_new'] = df['pincode_str'].map(
    lambda x: pincode_reference.get(x, {}).get('district', None)
)

# Optional: Drop the temporary pincode_str column if not needed
df = df.drop('pincode_str', axis=1)

print(df.head())
# Out:
#          date           state    district  pincode  demo_age_5_17  \
# 0  01-03-2025   UTTAR PRADESH   GORAKHPUR   273213             49
# 1  01-03-2025  ANDHRA PRADESH    CHITTOOR   517132             22
# 2  01-03-2025         GUJARAT      RAJKOT   360006             65
# 3  01-03-2025  ANDHRA PRADESH  SRIKAKULAM   532484             24
# 4  01-03-2025       RAJASTHAN     UDAIPUR   313801             45
#
#    demo_age_17_       state_new district_new
# 0           529   UTTAR PRADESH    GORAKHPUR
# 1           375  ANDHRA PRADESH     CHITTOOR
# 2           765         GUJARAT       RAJKOT
# 3           314  ANDHRA PRADESH   SRIKAKULAM
# 4           785       RAJASTHAN      UDAIPUR

# %%
df.head()
# Out:
#          date           state    district  pincode  demo_age_5_17  \
# 0  01-03-2025   UTTAR PRADESH   GORAKHPUR   273213             49
# 1  01-03-2025  ANDHRA PRADESH    CHITTOOR   517132             22
# 2  01-03-2025         GUJARAT      RAJKOT   360006             65
# 3  01-03-2025  ANDHRA PRADESH  SRIKAKULAM   532484             24
# 4  01-03-2025       RAJASTHAN     UDAIPUR   313801             45
#
#    demo_age_17_       state_new district_new
# 0           529   UTTAR PRADESH    GORAKHPUR
# 1           375  ANDHRA PRADESH     CHITTOOR
# 2           765         GUJARAT       RAJKOT
# 3           314  ANDHRA PRADESH   SRIKAKULAM
# 4           785       RAJASTHAN      UDAIPUR

# %%
df.columns
# Out:
# Index(['date', 'state', 'district', 'pincode', 'demo_age_5_17', 'demo_age_17_',
#        'state_new', 'district_new'],
#       dtype='object')

# %%
df['state']=df['state'].str.lower()
df['district']=df['district'].str.lower()

# %%
df.head()
# Out:
#          date           state    district  pincode  demo_age_5_17  \
# 0  01-03-2025   uttar pradesh   gorakhpur   273213             49
# 1  01-03-2025  andhra pradesh    chittoor   517132             22
# 2  01-03-2025         gujarat      rajkot   360006             65
# 3  01-03-2025  andhra pradesh  srikakulam   532484             24
# 4  01-03-2025       rajasthan     udaipur   313801             45
#
#    demo_age_17_
# 0           529
# 1           375
# 2           765
# 3           314
# 4           785

# %%
df.shape
# Out:
# (1560734, 6)

# %%
import pandas as pd
from difflib import SequenceMatcher

# make a copy of the dataframe
df_pre_final = df.copy()

# function to calculate similarity percentage
def similarity_percent(a, b):
    if pd.isna(a) or pd.isna(b):
        return 0
    return SequenceMatcher(None, str(a).lower(), str(b).lower()).ratio() * 100

# create is_match column
df_pre_final['is_match'] = df_pre_final.apply(
    lambda row: similarity_percent(row['district'], row['district_new']) >= 50,
    axis=1
)

# view result
df_pre_final.head(50)
# Out:
#           date              state               district  pincode  \
# 0   01-03-2025      uttar pradesh              gorakhpur   273213
# 1   01-03-2025     andhra pradesh               chittoor   517132
# 2   01-03-2025            gujarat                 rajkot   360006
# 3   01-03-2025     andhra pradesh             srikakulam   532484
# 4   01-03-2025          rajasthan                udaipur   313801
# 5   01-03-2025          rajasthan                  sikar   332028
# 6   01-03-2025          karnataka               tumakuru   572201
# 7   01-03-2025      uttar pradesh              gorakhpur   273211
# 8   01-03-2025     andhra pradesh                kurnool   518313
# 9   01-03-2025        west bengal      paschim medinipur   721148
# 10  01-03-2025      uttar pradesh               ghazipur   233226
# 11  01-03-2025            gujarat                  patan   385360
# 12  01-03-2025          telangana                 mulugu   506172
# 13  01-03-2025          rajasthan             ganganagar   335027
# 14  01-03-2025             odisha               nayagarh   752081
# 15  01-03-2025        maharashtra                 nashik   422305
# 16  01-03-2025          karnataka             shivamogga   577425
# 17  01-03-2025             kerala               thrissur   680305
# 18  01-03-2025          karnataka                 hassan   573144
# 19  01-03-2025              bihar                  patna   804423
# 20  01-03-2025         tamil nadu           kancheepuram   603202
# 21  01-03-2025     madhya pradesh               jabalpur   483119
# 22  01-03-2025         tamil nadu                chennai   600006
# 23  01-03-2025              assam               tinsukia   786174
# 24  01-03-2025              bihar                  jamui   811313
# 25  01-03-2025              bihar                   gaya   823003
# 26  01-03-2025         tamil nadu               tiruppur   641606
# 27  01-03-2025        maharashtra                jalgaon   425310
# 28  01-03-2025          rajasthan            chittorgarh   312023
# 29  01-03-2025              bihar              darbhanga   847103
# 30  01-03-2025              bihar                 purnia   854317
# 31  01-03-2025      uttar pradesh          muzaffarnagar   247775
# 32  01-03-2025          rajasthan                 jaipur   303701
# 33  01-03-2025          rajasthan                  churu   331301
# 34  01-03-2025          rajasthan              bharatpur   321406
# 35  01-03-2025            gujarat               jamnagar   361120
# 36  01-03-2025        west bengal                 howrah   711303
# 37  01-03-2025            gujarat              ahmedabad   382110
# 38  01-03-2025  arunachal pradesh            west kameng   790001
# 39  01-03-2025          karnataka               belagavi   591248
# 40  01-03-2025      uttar pradesh               bahraich   271821
# 41  01-03-2025         tamil nadu           nagapattinam   611001
# 42  01-03-2025              bihar             sheikhpura   811102
# 43  01-03-2025     andhra pradesh               chittoor   517291
# 44  01-03-2025             punjab               amritsar   143119
# 45  01-03-2025        west bengal      paschim medinipur   721436
# 46  01-03-2025     andhra pradesh  alluri sitharama raju   531040
# 47  01-03-2025              bihar              sitamarhi   843301
# 48  01-03-2025          jharkhand                 khunti   835234
# 49  01-03-2025      uttar pradesh             saharanpur   247670
#
#     demo_age_5_17  demo_age_17_          state_new    district_new  is_match
# 0              49           529      uttar pradesh       gorakhpur      True
# 1              22           375     andhra pradesh        chittoor      True
# 2              65           765            gujarat          rajkot      True
# 3              24           314     andhra pradesh      srikakulam      True
# 4              45           785          rajasthan         udaipur      True
# 5              28           285          rajasthan           sikar      True
# 6              88           332          karnataka        tumakuru      True
# 7              61           836      uttar pradesh       gorakhpur      True
# 8              83           986     andhra pradesh         kurnool      True
# 9              13           281        west bengal  medinipur west      True
# 10            134          1591      uttar pradesh        ghazipur      True
# 11            117           719            gujarat           patan      True
# 12             24           281          telangana          mulugu      True
# 13             25           545          rajasthan      ganganagar      True
# 14             48           295             odisha        nayagarh      True
# 15             13           227        maharashtra          nashik      True
# 16             11            30          karnataka      shivamogga      True
# 17             11            72             kerala        thrissur      True
# 18             23            53          karnataka          hassan      True
# 19             16            97              bihar           arwal     False
# 20             42           700                 na              na     False
# 21            132          1228     madhya pradesh        jabalpur      True
# 22             16           128         tamil nadu         chennai      True
# 23             22           416              assam        tinsukia      True
# 24             61           579              bihar           jamui      True
# 25            301          2485              bihar            gaya      True
# 26             54           639         tamil nadu        tiruppur      True
# 27             30           685        maharashtra         jalgaon      True
# 28            274          2259          rajasthan     chittorgarh      True
# 29            128          1525              bihar       darbhanga      True
# 30             27           453              bihar         katihar     False
# 31             22           222      uttar pradesh          shamli     False
# 32             54           346          rajasthan          jaipur      True
# 33             22           700          rajasthan           churu      True
# 34             19           414          rajasthan       bharatpur      True
# 35             42           313            gujarat        jamnagar      True
# 36            118          1909        west bengal          howrah      True
# 37            147          1065            gujarat       ahmadabad      True
# 38             13            44  arunachal pradesh     west kameng      True
# 39             78           119          karnataka        belagavi      True
# 40             54           556      uttar pradesh        bahraich      True
# 41             21           379         tamil nadu    nagapattinam      True
# 42             32           290              bihar      sheikhpura      True
# 43             10           145     andhra pradesh       annamayya     False
# 44             10           197             punjab        amritsar      True
# 45             10           168        west bengal  medinipur west      True
# 46             14           454     andhra pradesh  visakhapatanam     False
# 47             26           417              bihar       sitamarhi      True
# 48             19           425          jharkhand          khunti      True
# 49             10           105        uttarakhand        haridwar      True

# %%
df_pre_final = df.copy()

# %%
df_pre_final.shape
# Out:
# (1560734, 6)

# %%
df_pre_final[df_pre_final['is_match']==True].shape
# Out:
# (1306318, 9)

# %%
df_pre_final[df_pre_final['is_match']==False]
# Out:
#                date           state           district  pincode  \
# 19       01-03-2025           bihar              patna   804423
# 20       01-03-2025      tamil nadu       kancheepuram   603202
# 30       01-03-2025           bihar             purnia   854317
# 31       01-03-2025   uttar pradesh      muzaffarnagar   247775
# 43       01-03-2025  andhra pradesh           chittoor   517291
# ...             ...             ...                ...      ...
# 1560710  29-12-2025     west bengal  south 24 parganas   700082
# 1560723  29-12-2025     west bengal  south 24 parganas   743385
# 1560730  29-12-2025     west bengal     uttar dinajpur   733150
# 1560731  29-12-2025     west bengal     uttar dinajpur   733211
# 1560732  29-12-2025     west bengal     uttar dinajpur   733212
#
#          demo_age_5_17  demo_age_17_       state_new district_new  is_match
# 19                  16            97           bihar        arwal     False
# 20                  42           700              na           na     False
# 30                  27           453           bihar      katihar     False
# 31                  22           222   uttar pradesh       shamli     False
# 43                  10           145  andhra pradesh    annamayya     False
# ...                ...           ...             ...          ...       ...
# 1560710              1             6     west bengal      kolkata     False
# 1560723              0             3            None         None     False
# 1560730              0             1            None         None     False
# 1560731              0             9            None         None     False
# 1560732              0             9            None         None     False
#
# [254416 rows x 9 columns]

# %%
df_pre_final.columns
# Out:
# Index(['date', 'state', 'district', 'pincode', 'demo_age_5_17',
#        'demo_age_17_'],
#       dtype='object')

# %%
import pandas as pd
import json

# Load your pincode JSON file
with open('pin-code-data.json', 'r') as f:
    pincode_data = json.load(f)

# Create a mapping of state to its valid pincodes
state_to_pincodes = {}
for pincode, info in pincode_data.items():
    state = info['state'].upper()

    if state not in state_to_pincodes:
        state_to_pincodes[state] = set()
    state_to_pincodes[state].add(pincode)

# Function to check if pincode belongs to state
def check_pincode_in_state(pincode, state):
    """
    Check if pincode belongs to the given state
    Returns: True if pincode exists for that state, False otherwise
    """
    pincode_str = str(pincode).strip()
    state_upper = state.upper().strip()

    if state_upper in state_to_pincodes:
        return pincode_str in state_to_pincodes[state_upper]
    else:
        return False

# Create new 'match' column

df_pre_final['match'] = df_pre_final.apply(
    lambda row: check_pincode_in_state(row['pincode'], row['state']),
    axis=1
)

# Display results
print(df_pre_final[['state', 'pincode', 'match']])

# Get summary
print("\nMatch Summary:")
print(df_pre_final['match'].value_counts())

# Show unmatched records
unmatched = df_pre_final[df_pre_final['match'] == False]
print(f"\nUnmatched Records: {len(unmatched)}")
print(unmatched[['state', 'pincode', 'match']])
# Out:
#                   state  pincode  match
# 0         uttar pradesh   273213   True
# 1        andhra pradesh   517132   True
# 2               gujarat   360006   True
# 3        andhra pradesh   532484   True
# 4             rajasthan   313801   True
# ...                 ...      ...    ...
# 1560729     west bengal   733128   True
# 1560730     west bengal   733150  False
# 1560731     west bengal   733211  False
# 1560732     west bengal   733212  False
# 1560733     west bengal   712701   True
#
# [1560734 rows x 3 columns]
#
# Match Summary:
# match
# True     1504480
# False      56254
# Name: count, dtype: int64
#
# Unmatched Records: 56254
#                  state  pincode  match
# 20          tamil nadu   603202  False
# 49       uttar pradesh   247670  False
# 57             gujarat   391155  False
# 74          chandigarh   160103  False
# 105            gujarat   384212  False
# ...                ...      ...    ...
# 1560689    west bengal   721167  False
# 1560723    west bengal   743385  False
# 1560730    west bengal   733150  False
# 1560731    west bengal   733211  False
# 1560732    west bengal   733212  False
#
# [56254 rows x 3 columns]

# %%
df_one_save = df_pre_final[df_pre_final['match']==False]

# %%
df_one_save.to_csv('first_flase_demo.csv')

# %%
df_demo_final.to_csv('pre-final-demo.csv')

# %%
df_demo_final.shape
# Out:
# (1504480, 7)

# %%
df_demo_final.head()
# Out:
#          date           state    district  pincode  demo_age_5_17  \
# 0  01-03-2025   uttar pradesh   gorakhpur   273213             49
# 1  01-03-2025  andhra pradesh    chittoor   517132             22
# 2  01-03-2025         gujarat      rajkot   360006             65
# 3  01-03-2025  andhra pradesh  srikakulam   532484             24
# 4  01-03-2025       rajasthan     udaipur   313801             45
#
#    demo_age_17_  match
# 0           529   True
# 1           375   True
# 2           765   True
# 3           314   True
# 4           785   True

# %%
df_pre_final = pd.read_csv('/content/pre-final-demo.csv')

# %%
df_pre_final.shape
# Out:
# (1504480, 8)

# %%
import pandas as pd
import json

# Load your pincode JSON file
with open('pin-code-data.json', 'r') as f:
    pincode_data = json.load(f)

# Create a mapping of state to its valid pincodes
district_to_pincodes = {}
for pincode, info in pincode_data.items():
    district = info['district'].upper()

    if district not in district_to_pincodes:
        district_to_pincodes[district] = set()
    district_to_pincodes[district].add(pincode)

# Function to check if pincode belongs to state
def check_pincode_in_district(pincode, district):
    """
    Check if pincode belongs to the given state
    Returns: True if pincode exists for that state, False otherwise
    """
    pincode_str = str(pincode).strip()
    district_upper = district.upper().strip()

    if district_upper in district_to_pincodes:
        return pincode_str in district_to_pincodes[district_upper]
    else:
        return False

# Create new 'match' column

df_pre_final['match_district'] = df_pre_final.apply(
    lambda row: check_pincode_in_district(row['pincode'], row['district']),
    axis=1
)

# Display results
print(df_pre_final[['district', 'pincode', 'match_district']])

# Get summary
print("\nMatch Summary:")
print(df_pre_final['match_district'].value_counts())

# Show unmatched records
unmatched = df_pre_final[df_pre_final['match_district'] == False]
print(f"\nUnmatched Records: {len(unmatched)}")
print(unmatched[['district', 'pincode', 'match_district']])
# Out:
#                   district  pincode  match_district
# 0                gorakhpur   273213            True
# 1                 chittoor   517132            True
# 2                   rajkot   360006            True
# 3               srikakulam   532484            True
# 4                  udaipur   313801            True
# ...                    ...      ...             ...
# 1504475  south 24 parganas   743513           False
# 1504476  south 24 parganas   743609           False
# 1504477  south 24 parganas   743611           False
# 1504478     uttar dinajpur   733128           False
# 1504479            hooghly   712701            True
#
# [1504480 rows x 3 columns]
#
# Match Summary:
# match_district
# True     1198103
# False     306377
# Name: count, dtype: int64
#
# Unmatched Records: 306377
#                   district  pincode  match_district
# 9        paschim medinipur   721148           False
# 19                   patna   804423           False
# 29                  purnia   854317           False
# 30           muzaffarnagar   247775           False
# 36               ahmedabad   382110           False
# ...                    ...      ...             ...
# 1504474  south 24 parganas   743503           False
# 1504475  south 24 parganas   743513           False
# 1504476  south 24 parganas   743609           False
# 1504477  south 24 parganas   743611           False
# 1504478     uttar dinajpur   733128           False
#
# [306377 rows x 3 columns]

# %%
df_pre_final.to_csv('demo_completely_clean.csv')

# %%
df000 = df_pre_final[df_pre_final['match_district']==False]

# %%
df000.shape
# Out:
# (306377, 9)

# %%
df000.to_csv('second_false_demo.csv')

# %%
df_demo_final[df_demo_final['match']==False]
# Out:
# Empty DataFrame
# Columns: [date, state, district, pincode, demo_age_5_17, demo_age_17_, match]
# Index: []
