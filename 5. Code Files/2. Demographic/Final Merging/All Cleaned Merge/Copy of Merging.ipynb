# %%
import pandas as pd

# %%
# df1 = pd.read_csv('/content/demo_anomalies_cleaned.csv')
# df2 = pd.read_csv('/content/demo_final_cleaned_state_check.csv')

# %%
df1 = pd.read_csv('/content/demo_final_cleaned.csv')
df2 = pd.read_csv('/content/demo_anomalies_anomalies_clean.csv')

# %%
df1.shape
# Out:
# (1632603, 6)

# %%
df2.shape
# Out:
# (84801, 6)

# %%
df= pd.concat([df1,df2])

# %%
df.shape
# Out:
# (1717404, 6)

# %%
df.head()
# Out:
#          date        state       district  pincode  demo_age_5_17  \
# 0  01-03-2025       odisha    nabarangpur   764077             37
# 1  01-03-2025    rajasthan         jalore   343021             20
# 2  01-03-2025   tamil nadu  kanniyakumari   629803             10
# 3  01-03-2025  west bengal        purulia   723151             34
# 4  01-03-2025       punjab      ferozepur   152022             14
#
#    demo_age_17_
# 0           465
# 1           355
# 2            19
# 3           490
# 4           325

# %%
df.drop(['match'],axis=1, inplace=True)

# %%
df.head()
# Out:
#          date        state       district  pincode  demo_age_5_17  \
# 0  01-03-2025       odisha    nabarangpur   764077             37
# 1  01-03-2025    rajasthan         jalore   343021             20
# 2  01-03-2025   tamil nadu  kanniyakumari   629803             10
# 3  01-03-2025  west bengal        purulia   723151             34
# 4  01-03-2025       punjab      ferozepur   152022             14
#
#    demo_age_17_
# 0           465
# 1           355
# 2            19
# 3           490
# 4           325

# %%
df.to_csv('demo_final_cleaned_new.csv',index=False)
