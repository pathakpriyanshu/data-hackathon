# %%
import pandas as pd

# %%
# df1 = pd.read_csv('/content/bio_anomalies_cleaned.csv')
# df2 = pd.read_csv('/content/bio_final_cleaned_state_check.csv')

# %%
df1 = pd.read_csv('/content/bio_final_cleaned.csv')
df2 = pd.read_csv('/content/bio_anomalies_anomalies_clean.csv')

# %%
df1.shape
# Out:
# (1475177, 6)

# %%
df= pd.concat([df1,df2])

# %%
df.shape
# Out:
# (1548606, 6)

# %%
df.head()
# Out:
#          date           state                   district  pincode  \
# 0  01-03-2025          odisha                nabarangpur   764075
# 1  01-03-2025          punjab  shahid bhagat singh nagar   144514
# 2  01-03-2025       karnataka                 davanagere   577002
# 3  01-03-2025          odisha                 sundargarh   769004
# 4  01-03-2025  andhra pradesh              ananthapuramu   515301
#
#    bio_age_5_17  bio_age_17_
# 0           438          605
# 1           134          249
# 2           219          386
# 3           152          186
# 4            83          105

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1548606 entries, 0 to 73428
# Data columns (total 6 columns):
#  #   Column        Non-Null Count    Dtype
# ---  ------        --------------    -----
#  0   date          1548606 non-null  object
#  1   state         1548606 non-null  object
#  2   district      1548606 non-null  object
#  3   pincode       1548606 non-null  int64
#  4   bio_age_5_17  1548606 non-null  int64
#  5   bio_age_17_   1548606 non-null  int64
# dtypes: int64(3), object(3)
# memory usage: 82.7+ MB

# %%
df.drop(['match'],axis=1, inplace=True)

# %%
df.head()
# Out:
#          date           state                   district  pincode  \
# 0  01-03-2025          odisha                nabarangpur   764075
# 1  01-03-2025          punjab  shahid bhagat singh nagar   144514
# 2  01-03-2025       karnataka                 davanagere   577002
# 3  01-03-2025          odisha                 sundargarh   769004
# 4  01-03-2025  andhra pradesh              ananthapuramu   515301
#
#    bio_age_5_17  bio_age_17_
# 0           438          605
# 1           134          249
# 2           219          386
# 3           152          186
# 4            83          105

# %%
df.to_csv('bio_final_cleaned_new.csv',index=False)
