# %% [markdown]
# # UIDAI Biometric Data Analysis file 1

# %%
#importing necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1 = pd.read_csv('/content/bio_cleaned_1')
df2 = pd.read_csv('/content/bio_cleaned_2')
df3 = pd.read_csv('/content/bio_cleaned_3')
df4 = pd.read_csv('/content/bio_cleaned_4')

# %%
df1.shape
# Out:
# (391036, 7)

# %%
df2.shape
# Out:
# (371326, 7)

# %%
df3.shape
# Out:
# (374211, 7)

# %%
df4.shape
# Out:
# (271745, 7)

# %%
df = pd.concat([df1, df2, df3, df4], ignore_index=True)

# %%
df.drop('Unnamed: 0',axis=1,inplace=True)

# %%
df.shape
# Out:
# (1408318, 6)

# %%
df.head()
# Out:
#          date        state      district  pincode  bio_age_5_17  bio_age_17_
# 0  01-03-2025      haryana  mahendragarh   123029           280          577
# 1  01-03-2025        bihar     madhepura   852121           144          369
# 2  01-03-2025        bihar       bhojpur   802158           256          980
# 3  01-03-2025   tamil nadu       madurai   625514           271          815
# 4  01-03-2025  maharashtra     ratnagiri   416702           155          529

# %%
df.to_csv('bio_final.csv')
