# %% [markdown]
# # UIDAI Biometric Data Analysis file 1

# %%
#importing necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1 = pd.read_csv('/content/api_data_aadhar_biometric_500000_1000000.csv')

# %%
df1.head()
# Out:
#          date state   district  pincode  bio_age_5_17  bio_age_17_
# 0  19-09-2025   Goa  North Goa   403502             0            4
# 1  19-09-2025   Goa  North Goa   403508             1            4
# 2  19-09-2025   Goa  North Goa   403513             2            0
# 3  19-09-2025   Goa  North Goa   403527             2            2
# 4  19-09-2025   Goa  South Goa   403601             7            3

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500000 entries, 0 to 499999
# Data columns (total 6 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   date          500000 non-null  object
#  1   state         500000 non-null  object
#  2   district      500000 non-null  object
#  3   pincode       500000 non-null  int64
#  4   bio_age_5_17  500000 non-null  int64
#  5   bio_age_17_   500000 non-null  int64
# dtypes: int64(3), object(3)
# memory usage: 22.9+ MB

# %%
df1.describe()
# Out:
#              pincode   bio_age_5_17    bio_age_17_
# count  500000.000000  500000.000000  500000.000000
# mean   521530.811858       7.315852       7.530258
# std    198388.564260      13.580852      14.156381
# min    110001.000000       0.000000       0.000000
# 25%    392220.000000       1.000000       1.000000
# 50%    522016.000000       3.000000       3.000000
# 75%    686583.000000       8.000000       8.000000
# max    855456.000000     829.000000     577.000000

# %%
df1.shape
# Out:
# (500000, 6)

# %%
df1.columns
# Out:
# Index(['date', 'state', 'district', 'pincode', 'bio_age_5_17', 'bio_age_17_'], dtype='object')

# %%
df1.isnull().sum()
# Out:
# date            0
# state           0
# district        0
# pincode         0
# bio_age_5_17    0
# bio_age_17_     0
# dtype: int64

# %%
#duplicated data
df1[df1.duplicated()]
# Out:
#               date          state    district  pincode  bio_age_5_17  \
# 30000   15-10-2025  Uttar Pradesh  Rae Bareli   229202             6
# 30001   15-10-2025  Uttar Pradesh  Rae Bareli   229205            11
# 30002   15-10-2025  Uttar Pradesh  Rae Bareli   229211             2
# 30003   15-10-2025  Uttar Pradesh  Rae Bareli   229301            41
# 30004   15-10-2025  Uttar Pradesh  Rae Bareli   229311             9
# ...            ...            ...         ...      ...           ...
# 491678  06-11-2025      Karnataka   Bengaluru   560071             0
# 491679  06-11-2025      Karnataka   Bengaluru   560073            43
# 491680  06-11-2025      Karnataka   Bengaluru   560078            10
# 491681  06-11-2025      Karnataka   Bengaluru   560085             4
# 491682  06-11-2025      Karnataka   Bengaluru   560094             6
#
#         bio_age_17_
# 30000             4
# 30001             1
# 30002             2
# 30003            14
# 30004             5
# ...             ...
# 491678            1
# 491679            5
# 491680            9
# 491681            8
# 491682            7
#
# [31222 rows x 6 columns]

# %%
# without duplicates data
df1 = df1[~df1.duplicated()]
df1.shape
# Out:
# (468778, 6)

# %%
# Making copy of data for cleaning
df = df1.copy()

# %%
df[~df.duplicated()]
# Out:
#               date   state   district  pincode  bio_age_5_17  bio_age_17_
# 0       19-09-2025     Goa  North Goa   403502             0            4
# 1       19-09-2025     Goa  North Goa   403508             1            4
# 2       19-09-2025     Goa  North Goa   403513             2            0
# 3       19-09-2025     Goa  North Goa   403527             2            2
# 4       19-09-2025     Goa  South Goa   403601             7            3
# ...            ...     ...        ...      ...           ...          ...
# 499995  07-11-2025  Kerala  Ernakulam   682020             1            6
# 499996  07-11-2025  Kerala  Ernakulam   682022             1            0
# 499997  07-11-2025  Kerala  Ernakulam   682023             0            1
# 499998  07-11-2025  Kerala  Ernakulam   682025             3            6
# 499999  07-11-2025  Kerala  Ernakulam   682026             1            3
#
# [468778 rows x 6 columns]

# %%
# removing duplicates
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (468778, 6)

# %%
df.head()
# Out:
#          date state   district  pincode  bio_age_5_17  bio_age_17_
# 0  19-09-2025   Goa  North Goa   403502             0            4
# 1  19-09-2025   Goa  North Goa   403508             1            4
# 2  19-09-2025   Goa  North Goa   403513             2            0
# 3  19-09-2025   Goa  North Goa   403527             2            2
# 4  19-09-2025   Goa  South Goa   403601             7            3

# %%
# First Feature Cleaning
df['state'].unique()
# Out:
# array(['Goa', 'Gujarat', 'Haryana', 'Himachal Pradesh', 'Jammu & Kashmir',
#        'Jammu and Kashmir', 'Jharkhand', 'Karnataka', 'Kerala',
#        'Andaman & Nicobar Islands', 'Andaman and Nicobar Islands',
#        'Andhra Pradesh', 'Mizoram', 'Nagaland', 'Odisha', 'Orissa',
#        'Pondicherry', 'Puducherry', 'Punjab', 'Rajasthan', 'Sikkim',
#        'Tamil Nadu', 'Telangana', 'Tripura', 'Uttar Pradesh',
#        'Uttarakhand', 'West Bengal', 'Ladakh', 'Lakshadweep',
#        'Madhya Pradesh', 'Maharashtra', 'Manipur', 'Meghalaya',
#        'Arunachal Pradesh', 'Assam', 'Bihar', 'Chandigarh',
#        'Chhattisgarh', 'Dadra and Nagar Haveli', 'Daman & Diu', 'Delhi',
#        'Daman and Diu', 'West  Bengal',
#        'Dadra and Nagar Haveli and Daman and Diu', 'Dadra & Nagar Haveli',
#        'West bengal', 'West Bangal', 'ODISHA', 'WEST BENGAL',
#        'andhra pradesh', 'odisha', 'Westbengal', 'WESTBENGAL'],
#       dtype=object)

# %%
df['state']=df['state'].str.strip().str.lower()

# %%
df['state'].unique()
# Out:
# array(['goa', 'gujarat', 'haryana', 'himachal pradesh', 'jammu & kashmir',
#        'jammu and kashmir', 'jharkhand', 'karnataka', 'kerala',
#        'andaman & nicobar islands', 'andaman and nicobar islands',
#        'andhra pradesh', 'mizoram', 'nagaland', 'odisha', 'orissa',
#        'pondicherry', 'puducherry', 'punjab', 'rajasthan', 'sikkim',
#        'tamil nadu', 'telangana', 'tripura', 'uttar pradesh',
#        'uttarakhand', 'west bengal', 'ladakh', 'lakshadweep',
#        'madhya pradesh', 'maharashtra', 'manipur', 'meghalaya',
#        'arunachal pradesh', 'assam', 'bihar', 'chandigarh',
#        'chhattisgarh', 'dadra and nagar haveli', 'daman & diu', 'delhi',
#        'daman and diu', 'west  bengal',
#        'dadra and nagar haveli and daman and diu', 'dadra & nagar haveli',
#        'west bangal', 'westbengal'], dtype=object)

# %%
df[df['state'].str.contains("&")]['state'].str.replace("&", "and")
# Out:
# 388                 jammu and kashmir
# 1008      andaman and nicobar islands
# 1009      andaman and nicobar islands
# 4070                jammu and kashmir
# 5448                    daman and diu
#                      ...
# 488849              jammu and kashmir
# 492518    andaman and nicobar islands
# 492519    andaman and nicobar islands
# 495730    andaman and nicobar islands
# 495731    andaman and nicobar islands
# Name: state, Length: 331, dtype: object

# %%
df['state']=df['state'].str.replace("&", "and")

# %%
df[df['state'].str.startswith("o")]['state'].unique()
# Out:
# array(['odisha', 'orissa'], dtype=object)

# %%
df['state']=df['state'].str.replace('orissa','odisha')
df['state'] = df['state'].str.replace('chhatisgarh', 'chhattisgarh')

# %%
df['state'].unique()
# Out:
# array(['goa', 'gujarat', 'haryana', 'himachal pradesh',
#        'jammu and kashmir', 'jharkhand', 'karnataka', 'kerala',
#        'andaman and nicobar islands', 'andhra pradesh', 'mizoram',
#        'nagaland', 'odisha', 'pondicherry', 'puducherry', 'punjab',
#        'rajasthan', 'sikkim', 'tamil nadu', 'telangana', 'tripura',
#        'uttar pradesh', 'uttarakhand', 'west bengal', 'ladakh',
#        'lakshadweep', 'madhya pradesh', 'maharashtra', 'manipur',
#        'meghalaya', 'arunachal pradesh', 'assam', 'bihar', 'chandigarh',
#        'chhattisgarh', 'dadra and nagar haveli', 'daman and diu', 'delhi',
#        'west  bengal', 'dadra and nagar haveli and daman and diu',
#        'west bangal', 'westbengal'], dtype=object)

# %%
df['state'] = df['state'].replace({
    'daman and diu': 'dadra and nagar haveli and daman and diu',
    'dadra and nagar haveli': 'dadra and nagar haveli and daman and diu',

})

# %%
df['state']=df['state'].str.replace(
    r'^\s*west\s*b[aeo]ngal\s*$',
    'west bengal',
    regex=True
)

# %%
df['state']=df['state'].replace({'pondicherry':'puducherry', 'uttaranchal':'uttarakhand'})

# %%
df['state'].unique()
# Out:
# array(['goa', 'gujarat', 'haryana', 'himachal pradesh',
#        'jammu and kashmir', 'jharkhand', 'karnataka', 'kerala',
#        'andaman and nicobar islands', 'andhra pradesh', 'mizoram',
#        'nagaland', 'odisha', 'puducherry', 'punjab', 'rajasthan',
#        'sikkim', 'tamil nadu', 'telangana', 'tripura', 'uttar pradesh',
#        'uttarakhand', 'west bengal', 'ladakh', 'lakshadweep',
#        'madhya pradesh', 'maharashtra', 'manipur', 'meghalaya',
#        'arunachal pradesh', 'assam', 'bihar', 'chandigarh',
#        'chhattisgarh', 'dadra and nagar haveli and daman and diu',
#        'delhi'], dtype=object)

# %% [markdown]
# # State Feature Cleaned

# %% [markdown]
# ## Moving to next Feature (District)

# %%
df.shape
# Out:
# (468778, 6)

# %%
df['district'] = (
    df['district']
    .str.lower()
    .str.strip()
    .str.replace(r'\s+', ' ', regex=True)
)

# %%
df['district'].nunique()
# Out:
# 925

# %% [markdown]
# # It has various Unique values, so applying other logic

# %%
df['district'].unique()
# Out:
# array(['north goa', 'south goa', 'ahmadabad', 'ahmedabad', 'amreli',
#        'anand', 'arvalli', 'banaskantha', 'bharuch', 'bhavnagar', 'botad',
#        'chhotaudepur', 'dahod', 'devbhumi dwarka', 'dohad', 'gandhinagar',
#        'gir somnath', 'jamnagar', 'junagadh', 'kachchh', 'kheda',
#        'mahesana', 'mahisagar', 'morbi', 'narmada', 'navsari',
#        'panchmahals', 'patan', 'porbandar', 'rajkot', 'sabarkantha',
#        'surat', 'surendra nagar', 'surendranagar', 'tapi', 'the dangs',
#        'vadodara', 'valsad', 'ambala', 'bhiwani', 'charkhi dadri',
#        'faridabad', 'fatehabad', 'gurgaon', 'hisar', 'jhajjar', 'jind',
#        'kaithal', 'karnal', 'mahendragarh', 'mewat', 'palwal',
#        'panchkula', 'panipat', 'rewari', 'rohtak', 'sirsa', 'sonipat',
#        'yamuna nagar', 'bilaspur', 'chamba', 'hamirpur', 'kangra',
#        'kinnaur', 'kullu', 'mandi', 'shimla', 'sirmaur', 'solan', 'una',
#        'kathua', 'anantnag', 'badgam', 'bandipore', 'baramula', 'budgam',
#        'doda', 'ganderbal', 'jammu', 'kulgam', 'kupwara', 'leh',
#        'pulwama', 'punch', 'rajouri', 'reasi', 'samba', 'srinagar',
#        'udhampur', 'bokaro', 'chatra', 'deoghar', 'dhanbad', 'dumka',
#        'east singhbhum', 'garhwa', 'giridih', 'godda', 'gumla',
#        'hazaribag', 'hazaribagh', 'jamtara', 'khunti', 'kodarma',
#        'koderma', 'latehar', 'lohardaga', 'pakur', 'palamu',
#        'pashchimi singhbhum', 'purbi singhbhum', 'ramgarh', 'ranchi',
#        'sahebganj', 'sahibganj', 'seraikela-kharsawan', 'simdega',
#        'west singhbhum', 'bagalkot', 'bagalkot *', 'ballari', 'bangalore',
#        'bangalore rural', 'belagavi', 'belgaum', 'bellary', 'bengaluru',
#        'bidar', 'bijapur', 'chamarajanagar', 'chamrajanagar',
#        'chamrajnagar', 'chickmagalur', 'chikkaballapur', 'chikkamagaluru',
#        'chikmagalur', 'chitradurga', 'dakshina kannada', 'davanagere',
#        'davangere', 'dharwad', 'gadag', 'gadag *', 'gulbarga', 'hasan',
#        'hassan', 'haveri', 'haveri *', 'kalaburagi', 'kodagu', 'kolar',
#        'koppal', 'mandya', 'mysore', 'mysuru', 'raichur', 'ramanagar',
#        'shimoga', 'shivamogga', 'tumakuru', 'tumkur', 'udupi',
#        'uttara kannada', 'vijayanagara', 'vijayapura', 'yadgir',
#        'alappuzha', 'ernakulam', 'idukki', 'kannur', 'kasaragod',
#        'kasargod', 'kollam', 'kottayam', 'kozhikode', 'south andaman',
#        'nicobar', 'north and middle andaman', 'adilabad',
#        'alluri sitharama raju', 'anakapalli', 'anantapur', 'ananthapur',
#        'ananthapuramu', 'annamayya', 'bapatla', 'chittoor', 'cuddapah',
#        'mammit', 'serchhip', 'dimapur', 'kohima', 'longleng',
#        'mokokchung', 'mon', 'tuensang', 'zunheboto', 'angul', 'anugul',
#        'balangir', 'baleshwar', 'baleswar', 'bargarh', 'baudh', 'bhadrak',
#        'boudh', 'cuttack', 'dhenkanal', 'gajapati', 'ganjam', 'jajpur',
#        'jagatsinghapur', 'jagatsinghpur', 'jajapur', 'jharsuguda',
#        'kalahandi', 'kandhamal', 'kendrapara', 'kendujhar', 'khorda',
#        'khordha', 'koraput', 'malkangiri', 'mayurbhanj', 'nuapada',
#        'nabarangapur', 'nayagarh', 'puri', 'rayagada', 'sambalpur',
#        'sonapur', 'subarnapur', 'sundargarh', 'sundergarh', 'debagarh',
#        'karaikal', 'pondicherry', 'puducherry', 'amritsar', 'barnala',
#        'bathinda', 'faridkot', 'fatehgarh sahib', 'fazilka', 'ferozepur',
#        'firozpur', 'gurdaspur', 'hoshiarpur', 'jalandhar', 'kapurthala',
#        'ludhiana', 'malerkotla', 'mansa', 'moga', 'muktsar', 'nawanshahr',
#        'pathankot', 'patiala', 'rupnagar', 's.a.s nagar(mohali)',
#        'sas nagar (mohali)', 'sangrur', 'shaheed bhagat singh nagar',
#        'sri muktsar sahib', 'tarn taran', 'ajmer', 'alwar', 'banswara',
#        'baran', 'barmer', 'bharatpur', 'bhilwara', 'bikaner', 'bundi',
#        'chittaurgarh', 'chittorgarh', 'churu', 'dausa', 'dholpur',
#        'dungarpur', 'ganganagar', 'hanumangarh', 'jaipur', 'jaisalmer',
#        'jalor', 'jhalawar', 'jhunjhunu', 'jhunjhunun', 'jodhpur',
#        'karauli', 'kota', 'nagaur', 'pali', 'pratapgarh', 'rajsamand',
#        'sawai madhopur', 'sikar', 'sirohi', 'tonk', 'udaipur', 'east',
#        'south sikkim', 'west', 'ariyalur', 'chengalpattu', 'chennai',
#        'coimbatore', 'cuddalore', 'dharmapuri', 'dindigul', 'erode',
#        'kallakurichi', 'kancheepuram', 'kanniyakumari', 'kanyakumari',
#        'karur', 'krishnagiri', 'madurai', 'mayiladuthurai',
#        'nagapattinam', 'namakkal', 'perambalur', 'pudukkottai',
#        'ramanathapuram', 'ranipet', 'salem', 'sivaganga', 'tenkasi',
#        'thanjavur', 'the nilgiris', 'theni', 'thiruvallur', 'thiruvarur',
#        'thoothukkudi', 'tiruchirappalli', 'tirunelveli', 'tirupattur',
#        'tiruppur', 'tiruvallur', 'tiruvannamalai', 'vellore',
#        'villupuram', 'viluppuram', 'virudhunagar', 'bhadradri kothagudem',
#        'hanumakonda', 'hyderabad', 'jagitial', 'jangoan',
#        'jayashankar bhupalpally', 'jogulamba gadwal', 'k.v. rangareddy',
#        'kamareddy', 'karimnagar', 'khammam', 'komaram bheem',
#        'mahabubabad', 'mahabubnagar', 'mancherial', 'medak',
#        'medchal-malkajgiri', 'medchal−malkajgiri', 'mulugu',
#        'nagarkurnool', 'nalgonda', 'narayanpet', 'nirmal', 'nizamabad',
#        'peddapalli', 'rajanna sircilla', 'rangareddy', 'sangareddy',
#        'siddipet', 'suryapet', 'vikarabad', 'wanaparthy', 'warangal',
#        'warangal rural', 'warangal urban', 'yadadri.', 'dhalai', 'gomati',
#        'north tripura', 'sepahijala', 'south tripura', 'unakoti',
#        'west tripura', 'agra', 'aligarh', 'allahabad', 'ambedkar nagar',
#        'amethi', 'amroha', 'auraiya', 'ayodhya', 'azamgarh', 'baghpat',
#        'bahraich', 'ballia', 'balrampur', 'banda', 'bara banki',
#        'barabanki', 'bareilly', 'basti', 'bhadohi', 'bijnor', 'budaun',
#        'bulandshahr', 'chandauli', 'chitrakoot', 'deoria', 'etah',
#        'etawah', 'faizabad', 'farrukhabad', 'fatehpur', 'firozabad',
#        'gautam buddha nagar', 'ghaziabad', 'ghazipur', 'gonda',
#        'gorakhpur', 'hapur', 'hardoi', 'hathras', 'jalaun', 'jaunpur',
#        'jhansi', 'kannauj', 'kanpur dehat', 'kanpur nagar', 'kasganj',
#        'kaushambi', 'kheri', 'kushinagar', 'lalitpur', 'lucknow',
#        'maharajganj', 'mahoba', 'mainpuri', 'mathura', 'mau', 'meerut',
#        'mirzapur', 'moradabad', 'muzaffarnagar', 'pilibhit', 'prayagraj',
#        'rae bareli', 'rampur', 'saharanpur', 'sambhal',
#        'sant kabir nagar', 'sant ravidas nagar', 'shahjahanpur', 'shamli',
#        'shrawasti', 'siddharthnagar', 'sitapur', 'sonbhadra', 'sultanpur',
#        'unnao', 'varanasi', 'almora', 'chamoli', 'champawat', 'dehradun',
#        'haridwar', 'nainital', 'pauri garhwal', 'pithoragarh',
#        'rudraprayag', 'tehri garhwal', 'udham singh nagar', 'alipurduar',
#        'bankura', 'barddhaman', 'bardhaman', 'birbhum', 'cooch behar',
#        'dakshin dinajpur', 'darjeeling', 'darjiling', 'east midnapore',
#        'haora', 'hooghly', 'howrah', 'hugli', 'jalpaiguri', 'jhargram',
#        'kalimpong', 'koch bihar', 'kolkata', 'malda', 'maldah',
#        'murshidabad', 'nadia', 'north 24 parganas', 'north dinajpur',
#        'north twenty four parganas', 'paschim bardhaman',
#        'paschim medinipur', 'purba bardhaman', 'purba medinipur',
#        'purulia', 'puruliya', 'south 24 parganas', 'south dinajpur',
#        'south twenty four parganas', 'uttar dinajpur', 'west midnapore',
#        'malappuram', 'palakkad', 'pathanamthitta', 'thiruvananthapuram',
#        'thrissur', 'wayanad', 'kargil', 'lakshadweep', 'alirajpur',
#        'anuppur', 'ashok nagar', 'balaghat', 'barwani', 'betul', 'bhind',
#        'bhopal', 'burhanpur', 'chhatarpur', 'chhindwara', 'damoh',
#        'datia', 'dewas', 'dhar', 'dindori', 'guna', 'gwalior',
#        'hoshangabad', 'indore', 'jabalpur', 'jhabua', 'khandwa',
#        'khargone', 'maihar', 'mandla', 'mandsaur', 'mauganj', 'morena',
#        'narmadapuram', 'narsimhapur', 'narsinghpur', 'neemuch', 'niwari',
#        'panna', 'raisen', 'rajgarh', 'ratlam', 'rewa', 'sagar', 'satna',
#        'sehore', 'seoni', 'shahdol', 'shajapur', 'sheopur', 'shivpuri',
#        'sidhi', 'singrauli', 'tikamgarh', 'ujjain', 'umaria', 'vidisha',
#        'west nimar', 'ahmadnagar', 'ahmed nagar', 'akola', 'amravati',
#        'aurangabad', 'beed', 'bhandara', 'bid', 'buldana', 'buldhana',
#        'chandrapur', 'chhatrapati sambhajinagar', 'dhule', 'gadchiroli',
#        'gondiya', 'hingoli', 'jalgaon', 'jalna', 'kolhapur', 'latur',
#        'mumbai', 'mumbai city', 'mumbai suburban', 'mumbai( sub urban )',
#        'nagpur', 'nanded', 'nandurbar', 'nandurbar *', 'nashik',
#        'osmanabad', 'palghar', 'parbhani', 'pune', 'raigad', 'raigarh',
#        'raigarh(mh)', 'ratnagiri', 'sangli', 'satara', 'sindhudurg',
#        'solapur', 'thane', 'wardha', 'washim', 'washim *', 'yavatmal',
#        'bishnupur', 'chandel', 'imphal east', 'imphal west', 'jiribam',
#        'kakching', 'senapati', 'tamenglong', 'thoubal',
#        'east khasi hills', 'north garo hills', 'ri bhoi',
#        'south west garo hills', 'south west khasi hills',
#        'west garo hills', 'west jaintia hills', 'aizawl', 'kolasib',
#        'lunglei', 'mamit', 'panch mahals', 'kurukshetra',
#        'lahul and spiti', 'rajauri', 'kishtwar', 'ramban', 'garhwa *',
#        'pakaur', 'palamau', 'dr. b. r. ambedkar konaseema',
#        'east godavari', 'eluru', 'guntur', 'k.v.rangareddy', 'kakinada',
#        'karim nagar', 'krishna', 'kurnool', 'mahabub nagar',
#        'mahbubnagar', 'n. t. r', 'nandyal', 'nellore', 'palnadu',
#        'parvathipuram manyam', 'prakasam', 'rangareddi',
#        'sri potti sriramulu nellore', 'sri sathya sai', 'srikakulam',
#        'tirupati', 'visakhapatnam', 'vizianagaram', 'west godavari',
#        'y. s. r', 'changlang', 'east kameng', 'tawang', 'tirap',
#        'west siang', 'barpeta', 'biswanath', 'bongaigaon', 'cachar',
#        'charaideo', 'chirang', 'darrang', 'dhemaji', 'dhubri',
#        'dibrugarh', 'goalpara', 'golaghat', 'hailakandi', 'hojai',
#        'kamrup', 'kamrup metro', 'karbi anglong', 'karimganj',
#        'kokrajhar', 'lakhimpur', 'nagaon', 'nalbari',
#        'north cachar hills', 'sibsagar', 'sonitpur', 'tinsukia',
#        'udalguri', 'araria', 'arwal', 'banka', 'begusarai', 'bhagalpur',
#        'bhojpur', 'buxar', 'darbhanga', 'east champaran', 'gaya',
#        'gopalganj', 'jamui', 'jehanabad', 'kaimur (bhabua)', 'katihar',
#        'khagaria', 'lakhisarai', 'madhepura', 'madhubani', 'munger',
#        'muzaffarpur', 'nalanda', 'nawada', 'pashchim champaran', 'patna',
#        'purnea', 'purnia', 'rohtas', 'saharsa', 'samastipur', 'saran',
#        'sheikpura', 'sheohar', 'sitamarhi', 'siwan', 'supaul', 'vaishali',
#        'west champaran', 'chandigarh', 'balod', 'baloda bazar', 'bastar',
#        'bemetara', 'dakshin bastar dantewada', 'dantewada', 'durg',
#        'gariyaband', 'janjgir-champa', 'jashpur', 'kabeerdham', 'kanker',
#        'kawardha', 'kondagaon', 'korba', 'koriya', 'mungeli', 'raipur',
#        'rajnandgaon', 'sarangarh-bilaigarh', 'sukma', 'surajpur',
#        'surguja', 'uttar bastar kanker', 'dadra and nagar haveli',
#        'daman', 'central delhi', 'najafgarh', 'north delhi', 'north east',
#        'north west delhi', 'shahdara', 'south delhi', 'south west delhi',
#        'west delhi', 'jangaon', 'jyotiba phule nagar',
#        'sant ravidas nagar bhadohi', 'bageshwar', 'garhwal', 'uttarkashi',
#        'yanam', 'east sikkim', 'south', 'west sikkim', 'east nimar',
#        'harda', 'katni', 'pandhurna', 'chatrapati sambhaji nagar',
#        'dharashiv', 'gondia', 'churachandpur', 'ukhrul', 'lawngtlai',
#        'saiha', 'niuland', 'andamans', 'banas kantha', 'yamunanagar',
#        'leh (ladakh)', 'chamarajanagar *', 'agar malwa', 'harda *',
#        'gondiya *', 'west khasi hills', 'kiphire', 'meluri', 'peren',
#        'east siang', 'lohit', 'lower siang', 'papum pare', 'shi-yomi',
#        'west kameng', 'baksa', 'marigaon', 'south salmara mankachar',
#        'aurangabad(bh)', 'kishanganj', 'purba champaran', 'sheikhpura',
#        'dhamtari', 'gaurela-pendra-marwahi', 'mahasamund',
#        'mohla-manpur-ambagarh chouki', 'narayanpur', 'north east delhi',
#        'bulandshahar', 'hardwar', 'bally jagachha', 'burdwan',
#        'kra daadi', 'longding', 'pakke kessang', 'siang', 'upper siang',
#        'upper subansiri', 'jorhat', 'sribhumi', 'monghyr', 'samstipur',
#        'khairagarh chhuikhadan gandai', 'sakti', 'east delhi',
#        'lahul & spiti', 'bengaluru south', 'east jaintia hills',
#        'champhai', 'noklak', 'phek', 'shamator', 'khowai', 'diu',
#        'new delhi', 'south east delhi', 'sabar kantha', 'shupiyan',
#        'bokaro *', 'dhaulpur', 'north', 'anjaw', 'kurung kumey',
#        'lower dibang valley', 'namsai', 'chumukedima', 'wokha', 'majuli',
#        'west karbi anglong', 'bhabua', 'dadra & nagar haveli',
#        'north sikkim', 'lower subansiri', 'medinipur', 'east garo hills',
#        'mahrajganj', 'south garo hills', 'tseminyu', 'tamulpur district',
#        'janjgir champa', 'janjgir - champa', 'bagpat', 'deeg', 'dhalai *',
#        'raebareli', 'east midnapur', 'warangal (urban)', 'kamle',
#        'dima hasao', 'khawzawl', 'hawrah', 'tirupathur',
#        'lahaul and spiti', 'bijapur(kar)', 'hooghiy', 'dibang valley',
#        'manendragarh–chirmiri–bharatpur', 'kushinagar *', 'bajali',
#        'mohalla-manpur-ambagarh chowki', 'bardez', 'anugal', 'leparada',
#        'jaintia hills', 'south dumdum(m)', 'hnahthial',
#        'gautam buddha nagar *', 'bengaluru rural', 'mohali', 'hingoli *',
#        'south 24 pargana', 'anugul *', 'kanchipuram', 'namchi',
#        'west medinipur', 'saitual', 'tuticorin', 'akhera', 'jalore'],
#       dtype=object)

# %%
df.shape
# Out:
# (468778, 6)

# %%
import pandas as pd
import json

# Step 1: Load your reference JSON file
with open('/content/state_district_reference.json', 'r', encoding='utf-8') as f:
    reference_data = json.load(f)


# Step 3: Create a simple validation function
def is_valid_district(state, district):
    """
    Check if district exists in the given state's district list

    Args:
        state (str): State name (must match JSON key exactly)
        district (str): District name to validate

    Returns:
        bool: True if district is in that state's list, False otherwise
    """
    # Get the districts list for this state from JSON
    if state in reference_data:
        valid_districts = reference_data[state]['districts']
        # Check if district is in the list
        return district in valid_districts
    return False

# Step 4: Apply validation to each row
df['is_valid'] = df.apply(
    lambda row: is_valid_district(row['state'], row['district']),
    axis=1
)

# Step 5: Get rows where matching didn't happen (invalid rows)
invalid_rows = df[df['is_valid'] == False]

# Step 6: Display results
print("=" * 70)
print("DISTRICT VALIDATION REPORT")
print("=" * 70)
print(f"\nTotal rows in dataset: {len(df)}")
print(f"Valid matches (district found in state's list): {df['is_valid'].sum()}")
print(f"INVALID/MISSPELLED rows (matching didn't happen): {len(invalid_rows)}")
print(f"Percentage of invalid rows: {(len(invalid_rows)/len(df)*100):.2f}%")
print("=" * 70)

# Step 7: Show sample of invalid records
if len(invalid_rows) > 0:
    print("\nSample of INVALID records (first 10):")
    print(invalid_rows[['state', 'district']].head(10).to_string(index=False))

    # Breakdown by state
    print("\n\nINVALID records breakdown by STATE:")
    print(invalid_rows['state'].value_counts().to_string())

# Step 8: Decide whether to drop based on count
print("\n" + "=" * 70)
if len(invalid_rows) >= 2000 and len(invalid_rows) <= 3000:
    print(f"✓ Invalid rows count: {len(invalid_rows)} (within 2k-3k range - SAFE TO DROP)")

    # Drop invalid rows and create cleaned dataset
    df_cleaned = df[df['is_valid'] == True].drop('is_valid', axis=1).reset_index(drop=True)

    print(f"✓ Original dataset shape: {df.shape}")
    print(f"✓ Cleaned dataset shape: {df_cleaned.shape}")
    print(f"✓ Rows dropped: {len(df) - len(df_cleaned)}")

    # Save cleaned data
    df_cleaned.to_csv('your_dataset_cleaned.csv', index=False)
    print(f"\n✓ Cleaned dataset saved to 'your_dataset_cleaned.csv'")

elif len(invalid_rows) < 2000:
    print(f"⚠ Invalid rows count: {len(invalid_rows)} (less than 2000)")
    print("  Suggestion: Consider fixing these records instead of dropping")

elif len(invalid_rows) > 3000:
    print(f"✗ Invalid rows count: {len(invalid_rows)} (more than 3000)")
    print("  Suggestion: Data quality issue - manual review needed before dropping")

# Step 9: Export invalid records for reference
if len(invalid_rows) > 0:
    invalid_rows[['state', 'district']].to_csv('invalid_records.csv', index=False)
    print(f"✓ Invalid records exported to 'invalid_records.csv' for review")

print("=" * 70)
# Out:
# ======================================================================
# DISTRICT VALIDATION REPORT
# ======================================================================
#
# Total rows in dataset: 468778
# Valid matches (district found in state's list): 371326
# INVALID/MISSPELLED rows (matching didn't happen): 97452
# Percentage of invalid rows: 20.79%
# ======================================================================
#
# Sample of INVALID records (first 10):
#   state    district
# gujarat   ahmadabad
# gujarat   ahmadabad
# gujarat   ahmadabad
# gujarat   ahmadabad
# gujarat   ahmadabad
# gujarat   ahmadabad
# gujarat   ahmadabad
# gujarat   ahmadabad
# gujarat   ahmadabad
# gujarat banaskantha
#
#
# INVALID records breakdown by STATE:
# state
# andhra pradesh                              18915
# karnataka                                   16480
# west bengal                                  9504
# maharashtra                                  7596
# odisha                                       7542
# tamil nadu                                   4781
# telangana                                    4041
# gujarat                                      3246
# uttar pradesh                                2616
# tripura                                      2199
# madhya pradesh                               2195
# delhi                                        2129
# punjab                                       2004
# manipur                                      1781
# bihar                                        1474
# rajasthan                                    1446
# chhattisgarh                                 1349
# jharkhand                                    1297
# meghalaya                                    1102
# assam                                        1100
# nagaland                                     1014
# jammu and kashmir                             946
# haryana                                       925
# sikkim                                        588
# puducherry                                    439
# kerala                                        231
# himachal pradesh                              152
# uttarakhand                                   123
# mizoram                                       104
# andaman and nicobar islands                    90
# dadra and nagar haveli and daman and diu       21
# arunachal pradesh                              12
# goa                                             7
# chandigarh                                      3
#
# ======================================================================
# ✗ Invalid rows count: 97452 (more than 3000)
#   Suggestion: Data quality issue - manual review needed before dropping
# ✓ Invalid records exported to 'invalid_records.csv' for review
# ======================================================================

# %%
df.head()
# Out:
#          date state   district  pincode  bio_age_5_17  bio_age_17_  is_valid
# 0  19-09-2025   goa  north goa   403502             0            4      True
# 1  19-09-2025   goa  north goa   403508             1            4      True
# 2  19-09-2025   goa  north goa   403513             2            0      True
# 3  19-09-2025   goa  north goa   403527             2            2      True
# 4  19-09-2025   goa  south goa   403601             7            3      True

# %%
df_cleaned = df[df['is_valid'] == True].drop('is_valid', axis=1).reset_index(drop=True)

# %%
df_anomalies = df[df['is_valid'] == False].drop('is_valid', axis=1).reset_index(drop=True)

# %%
df_cleaned.shape
# Out:
# (371326, 6)

# %%
df_cleaned.columns
# Out:
# Index(['date', 'state', 'district', 'pincode', 'bio_age_5_17', 'bio_age_17_'], dtype='object')

# %%
df_cleaned.to_csv("cleaned_2")

# %%
df_anomalies.shape
# Out:
# (97452, 6)

# %%
df_anomalies.to_csv("bio_anomalies_2.csv")
