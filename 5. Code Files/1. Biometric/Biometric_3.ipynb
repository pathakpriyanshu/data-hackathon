# %% [markdown]
# # UIDAI Biometric Data Analysis file 1

# %%
#importing necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1 = pd.read_csv('/content/api_data_aadhar_biometric_1000000_1500000.csv')

# %%
df1.head()
# Out:
#          date             state      district  pincode  bio_age_5_17  \
# 0  07-11-2025           Haryana  Yamuna Nagar   135002             4
# 1  07-11-2025           Haryana   Yamunanagar   135001             1
# 2  07-11-2025  Himachal Pradesh      Bilaspur   174004             2
# 3  07-11-2025  Himachal Pradesh      Bilaspur   174005             1
# 4  07-11-2025  Himachal Pradesh      Bilaspur   174013             3
#
#    bio_age_17_
# 0            6
# 1            2
# 2            2
# 3            0
# 4            1

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500000 entries, 0 to 499999
# Data columns (total 6 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   date          500000 non-null  object
#  1   state         500000 non-null  object
#  2   district      500000 non-null  object
#  3   pincode       500000 non-null  int64
#  4   bio_age_5_17  500000 non-null  int64
#  5   bio_age_17_   500000 non-null  int64
# dtypes: int64(3), object(3)
# memory usage: 22.9+ MB

# %%
df1.describe()
# Out:
#              pincode   bio_age_5_17    bio_age_17_
# count  500000.000000  500000.000000  500000.000000
# mean   520925.071276       8.222022       7.751516
# std    198445.752368      15.389444      13.592242
# min    110001.000000       0.000000       0.000000
# 25%    390018.000000       1.000000       1.000000
# 50%    522409.000000       3.000000       4.000000
# 75%    686564.000000       9.000000       9.000000
# max    855456.000000     743.000000     549.000000

# %%
df1.shape
# Out:
# (500000, 6)

# %%
df1.columns
# Out:
# Index(['date', 'state', 'district', 'pincode', 'bio_age_5_17', 'bio_age_17_'], dtype='object')

# %%
df1.isnull().sum()
# Out:
# date            0
# state           0
# district        0
# pincode         0
# bio_age_5_17    0
# bio_age_17_     0
# dtype: int64

# %%
#duplicated data
df1[df1.duplicated()]
# Out:
#               date        state        district  pincode  bio_age_5_17  \
# 10000   07-11-2025       Odisha          JAJPUR   755018            11
# 10001   07-11-2025       Odisha          JAJPUR   755049             0
# 10002   07-11-2025       Odisha          JAJPUR   755050             0
# 10003   07-11-2025       Odisha  Jagatsinghapur   754106             5
# 10004   07-11-2025       Odisha  Jagatsinghapur   754110            17
# ...            ...          ...             ...      ...           ...
# 490114  08-12-2025  West Bengal  West Midnapore   721301             1
# 490115  08-12-2025  West Bengal  West Midnapore   721305             1
# 490116  08-12-2025  West Bengal  West Midnapore   721506             3
# 490117  08-12-2025  West Bengal  West Midnapore   721513             0
# 490118  08-12-2025       odisha        Gajapati   761207             0
#
#         bio_age_17_
# 10000             1
# 10001             3
# 10002             1
# 10003            12
# 10004             4
# ...             ...
# 490114           15
# 490115            5
# 490116           10
# 490117            4
# 490118            1
#
# [30585 rows x 6 columns]

# %%
# without duplicates data
df1 = df1[~df1.duplicated()]
df1.shape
# Out:
# (469415, 6)

# %%
# Making copy of data for cleaning
df = df1.copy()

# %%
df[~df.duplicated()]
# Out:
#               date             state      district  pincode  bio_age_5_17  \
# 0       07-11-2025           Haryana  Yamuna Nagar   135002             4
# 1       07-11-2025           Haryana   Yamunanagar   135001             1
# 2       07-11-2025  Himachal Pradesh      Bilaspur   174004             2
# 3       07-11-2025  Himachal Pradesh      Bilaspur   174005             1
# 4       07-11-2025  Himachal Pradesh      Bilaspur   174013             3
# ...            ...               ...           ...      ...           ...
# 499995  08-12-2025           Gujarat      Vadodara   391150             3
# 499996  08-12-2025           Gujarat      Vadodara   391168            11
# 499997  08-12-2025           Gujarat      Vadodara   391170             0
# 499998  08-12-2025           Gujarat      Vadodara   391410             9
# 499999  08-12-2025           Gujarat      Vadodara   391530             3
#
#         bio_age_17_
# 0                 6
# 1                 2
# 2                 2
# 3                 0
# 4                 1
# ...             ...
# 499995           18
# 499996           34
# 499997           23
# 499998            4
# 499999            7
#
# [469415 rows x 6 columns]

# %%
# removing duplicates
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (469415, 6)

# %%
df.head()
# Out:
#          date             state      district  pincode  bio_age_5_17  \
# 0  07-11-2025           Haryana  Yamuna Nagar   135002             4
# 1  07-11-2025           Haryana   Yamunanagar   135001             1
# 2  07-11-2025  Himachal Pradesh      Bilaspur   174004             2
# 3  07-11-2025  Himachal Pradesh      Bilaspur   174005             1
# 4  07-11-2025  Himachal Pradesh      Bilaspur   174013             3
#
#    bio_age_17_
# 0            6
# 1            2
# 2            2
# 3            0
# 4            1

# %%
# First Feature Cleaning
df['state'].unique()
# Out:
# array(['Haryana', 'Himachal Pradesh', 'Jammu and Kashmir', 'Jharkhand',
#        'Karnataka', 'Kerala', 'Lakshadweep', 'Madhya Pradesh',
#        'Maharashtra', 'Andaman & Nicobar Islands',
#        'Andaman and Nicobar Islands', 'Andhra Pradesh',
#        'Arunachal Pradesh', 'Assam', 'Bihar', 'Uttar Pradesh',
#        'Uttarakhand', 'West Bengal', 'Chandigarh', 'Chhattisgarh',
#        'Dadra & Nagar Haveli', 'Dadra and Nagar Haveli', 'Daman & Diu',
#        'Daman and Diu', 'Delhi', 'Goa', 'Gujarat', 'Jammu & Kashmir',
#        'Manipur', 'Meghalaya', 'Mizoram', 'Nagaland', 'Odisha', 'Orissa',
#        'Pondicherry', 'Puducherry', 'Punjab', 'Rajasthan', 'Sikkim',
#        'Tamil Nadu', 'Telangana', 'Tripura', 'Ladakh', 'West Bangal',
#        'West bengal', 'odisha',
#        'Dadra and Nagar Haveli and Daman and Diu', 'West  Bengal',
#        'WEST BENGAL', 'andhra pradesh', 'Westbengal', 'Chhatisgarh',
#        'ODISHA', 'WESTBENGAL', 'Uttaranchal'], dtype=object)

# %%
df['state']=df['state'].str.strip().str.lower()

# %%
df['state'].unique()
# Out:
# array(['haryana', 'himachal pradesh', 'jammu and kashmir', 'jharkhand',
#        'karnataka', 'kerala', 'lakshadweep', 'madhya pradesh',
#        'maharashtra', 'andaman & nicobar islands',
#        'andaman and nicobar islands', 'andhra pradesh',
#        'arunachal pradesh', 'assam', 'bihar', 'uttar pradesh',
#        'uttarakhand', 'west bengal', 'chandigarh', 'chhattisgarh',
#        'dadra & nagar haveli', 'dadra and nagar haveli', 'daman & diu',
#        'daman and diu', 'delhi', 'goa', 'gujarat', 'jammu & kashmir',
#        'manipur', 'meghalaya', 'mizoram', 'nagaland', 'odisha', 'orissa',
#        'pondicherry', 'puducherry', 'punjab', 'rajasthan', 'sikkim',
#        'tamil nadu', 'telangana', 'tripura', 'ladakh', 'west bangal',
#        'dadra and nagar haveli and daman and diu', 'west  bengal',
#        'westbengal', 'chhatisgarh', 'uttaranchal'], dtype=object)

# %%
df[df['state'].str.contains("&")]['state'].str.replace("&", "and")
# Out:
# 1124      andaman and nicobar islands
# 2439           dadra and nagar haveli
# 2441                    daman and diu
# 2870                jammu and kashmir
# 5869      andaman and nicobar islands
#                      ...
# 495916         dadra and nagar haveli
# 496332              jammu and kashmir
# 496333              jammu and kashmir
# 496334              jammu and kashmir
# 498216    andaman and nicobar islands
# Name: state, Length: 336, dtype: object

# %%
df['state']=df['state'].str.replace("&", "and")

# %%
df[df['state'].str.startswith("o")]['state'].unique()
# Out:
# array(['odisha', 'orissa'], dtype=object)

# %%
df['state']=df['state'].str.replace('orissa','odisha')
df['state'] = df['state'].str.replace('chhatisgarh', 'chhattisgarh')

# %%
df['state'].unique()
# Out:
# array(['haryana', 'himachal pradesh', 'jammu and kashmir', 'jharkhand',
#        'karnataka', 'kerala', 'lakshadweep', 'madhya pradesh',
#        'maharashtra', 'andaman and nicobar islands', 'andhra pradesh',
#        'arunachal pradesh', 'assam', 'bihar', 'uttar pradesh',
#        'uttarakhand', 'west bengal', 'chandigarh', 'chhattisgarh',
#        'dadra and nagar haveli', 'daman and diu', 'delhi', 'goa',
#        'gujarat', 'manipur', 'meghalaya', 'mizoram', 'nagaland', 'odisha',
#        'pondicherry', 'puducherry', 'punjab', 'rajasthan', 'sikkim',
#        'tamil nadu', 'telangana', 'tripura', 'ladakh', 'west bangal',
#        'dadra and nagar haveli and daman and diu', 'west  bengal',
#        'westbengal', 'uttaranchal'], dtype=object)

# %%
df['state'] = df['state'].replace({
    'daman and diu': 'dadra and nagar haveli and daman and diu',
    'dadra and nagar haveli': 'dadra and nagar haveli and daman and diu',

})

# %%
df['state']=df['state'].str.replace(
    r'^\s*west\s*b[aeo]ngal\s*$',
    'west bengal',
    regex=True
)

# %%
df['state']=df['state'].replace({'pondicherry':'puducherry', 'uttaranchal':'uttarakhand'})

# %%
df['state'].unique()
# Out:
# array(['haryana', 'himachal pradesh', 'jammu and kashmir', 'jharkhand',
#        'karnataka', 'kerala', 'lakshadweep', 'madhya pradesh',
#        'maharashtra', 'andaman and nicobar islands', 'andhra pradesh',
#        'arunachal pradesh', 'assam', 'bihar', 'uttar pradesh',
#        'uttarakhand', 'west bengal', 'chandigarh', 'chhattisgarh',
#        'dadra and nagar haveli and daman and diu', 'delhi', 'goa',
#        'gujarat', 'manipur', 'meghalaya', 'mizoram', 'nagaland', 'odisha',
#        'puducherry', 'punjab', 'rajasthan', 'sikkim', 'tamil nadu',
#        'telangana', 'tripura', 'ladakh'], dtype=object)

# %% [markdown]
# # State Feature Cleaned

# %% [markdown]
# ## Moving to next Feature (District)

# %%
df.shape
# Out:
# (469415, 6)

# %%
df['district'] = (
    df['district']
    .str.lower()
    .str.strip()
    .str.replace(r'\s+', ' ', regex=True)
)

# %%
df['district'].nunique()
# Out:
# 932

# %% [markdown]
# # It has various Unique values, so applying other logic

# %%
df['district'].unique()
# Out:
# array(['yamuna nagar', 'yamunanagar', 'bilaspur', 'chamba', 'hamirpur',
#        'kangra', 'kinnaur', 'kullu', 'lahul & spiti', 'lahul and spiti',
#        'mandi', 'shimla', 'sirmaur', 'solan', 'una', 'anantnag', 'badgam',
#        'bandipore', 'baramula', 'budgam', 'doda', 'jammu', 'kargil',
#        'kathua', 'kishtwar', 'kupwara', 'leh', 'punch', 'rajouri',
#        'reasi', 'samba', 'shupiyan', 'srinagar', 'udhampur', 'bokaro',
#        'chatra', 'deoghar', 'dhanbad', 'dumka', 'east singhbhum',
#        'garhwa', 'giridih', 'godda', 'gumla', 'hazaribag', 'hazaribagh',
#        'jamtara', 'khunti', 'kodarma', 'koderma', 'lohardaga', 'pakur',
#        'palamu', 'pashchimi singhbhum', 'purbi singhbhum', 'ramgarh',
#        'ranchi', 'sahebganj', 'seraikela-kharsawan', 'simdega',
#        'west singhbhum', 'bagalkot', 'ballari', 'bangalore',
#        'bangalore rural', 'belagavi', 'belgaum', 'bellary', 'bengaluru',
#        'bengaluru south', 'bidar', 'bijapur', 'chamarajanagar',
#        'chamrajanagar', 'chickmagalur', 'chikkaballapur',
#        'chikkamagaluru', 'chitradurga', 'dakshina kannada', 'davanagere',
#        'davangere', 'dharwad', 'gadag', 'gadag *', 'gulbarga', 'hasan',
#        'hassan', 'haveri', 'kalaburagi', 'kodagu', 'kolar', 'koppal',
#        'mandya', 'mysore', 'mysuru', 'raichur', 'ramanagar', 'shimoga',
#        'shivamogga', 'tumakuru', 'tumkur', 'udupi', 'uttara kannada',
#        'vijayanagara', 'vijayapura', 'yadgir', 'alappuzha', 'ernakulam',
#        'idukki', 'kannur', 'kasaragod', 'kasargod', 'kollam', 'kottayam',
#        'kozhikode', 'malappuram', 'palakkad', 'pathanamthitta',
#        'thiruvananthapuram', 'thrissur', 'wayanad', 'lakshadweep',
#        'agar malwa', 'anuppur', 'ashok nagar', 'balaghat', 'barwani',
#        'betul', 'bhind', 'bhopal', 'burhanpur', 'chhatarpur',
#        'chhindwara', 'damoh', 'datia', 'dewas', 'dhar', 'dindori',
#        'east nimar', 'guna', 'gwalior', 'hoshangabad', 'indore',
#        'jabalpur', 'jhabua', 'katni', 'khandwa', 'khargone', 'maihar',
#        'mandla', 'mandsaur', 'mauganj', 'narsimhapur', 'narsinghpur',
#        'neemuch', 'niwari', 'panna', 'raisen', 'rajgarh', 'ratlam',
#        'rewa', 'sagar', 'satna', 'sehore', 'seoni', 'shahdol', 'shajapur',
#        'shivpuri', 'sidhi', 'tikamgarh', 'ujjain', 'umaria', 'vidisha',
#        'west nimar', 'ahmadnagar', 'ahmed nagar', 'akola', 'amravati',
#        'aurangabad', 'beed', 'bhandara', 'bid', 'buldana', 'buldhana',
#        'chandrapur', 'chhatrapati sambhajinagar', 'dharashiv', 'dhule',
#        'gadchiroli', 'gondia', 'gondiya *', 'hingoli', 'jalgaon', 'jalna',
#        'kolhapur', 'latur', 'mumbai', 'mumbai city', 'mumbai suburban',
#        'mumbai( sub urban )', 'nagpur', 'andamans',
#        'north and middle andaman', 'south andaman', 'adilabad',
#        'alluri sitharama raju', 'anakapalli', 'anantapur', 'ananthapur',
#        'ananthapuramu', 'annamayya', 'bapatla', 'chittoor', 'cuddapah',
#        'dr. b. r. ambedkar konaseema', 'east godavari', 'eluru', 'guntur',
#        'hyderabad', 'k.v. rangareddy', 'kakinada', 'karim nagar',
#        'karimnagar', 'khammam', 'krishna', 'kurnool', 'mahabub nagar',
#        'mahbubnagar', 'medak', 'n. t. r', 'nalgonda', 'nandyal',
#        'nellore', 'nizamabad', 'palnadu', 'parvathipuram manyam',
#        'prakasam', 'rangareddi', 'sri potti sriramulu nellore',
#        'sri sathya sai', 'srikakulam', 'tirupati', 'visakhapatnam',
#        'vizianagaram', 'warangal', 'west godavari', 'y. s. r',
#        'changlang', 'east kameng', 'east siang', 'kamle', 'kra daadi',
#        'lohit', 'longding', 'namsai', 'papum pare', 'upper siang',
#        'west kameng', 'west siang', 'baksa', 'barpeta', 'biswanath',
#        'bongaigaon', 'cachar', 'charaideo', 'chirang', 'darrang',
#        'dhemaji', 'dhubri', 'dibrugarh', 'goalpara', 'golaghat',
#        'hailakandi', 'hojai', 'jorhat', 'kamrup', 'kamrup metro',
#        'karbi anglong', 'karimganj', 'kokrajhar', 'lakhimpur', 'majuli',
#        'nagaon', 'nalbari', 'sibsagar', 'sonitpur', 'sribhumi',
#        'tinsukia', 'udalguri', 'west karbi anglong', 'arwal', 'banka',
#        'begusarai', 'bhagalpur', 'bhojpur', 'buxar', 'darbhanga',
#        'east champaran', 'gaya', 'gopalganj', 'jamui', 'jehanabad',
#        'kaimur (bhabua)', 'katihar', 'kishanganj', 'lakhisarai',
#        'madhepura', 'madhubani', 'pratapgarh', 'prayagraj', 'rae bareli',
#        'rampur', 'saharanpur', 'sambhal', 'sant kabir nagar',
#        'sant ravidas nagar', 'shahjahanpur', 'shamli', 'siddharthnagar',
#        'sitapur', 'sonbhadra', 'sultanpur', 'unnao', 'varanasi', 'almora',
#        'bageshwar', 'chamoli', 'champawat', 'dehradun', 'hardwar',
#        'haridwar', 'nainital', 'pauri garhwal', 'pithoragarh',
#        'rudraprayag', 'tehri garhwal', 'udham singh nagar', 'alipurduar',
#        'bankura', 'barddhaman', 'bardhaman', 'birbhum', 'cooch behar',
#        'dakshin dinajpur', 'darjeeling', 'darjiling', 'east midnapore',
#        'haora', 'hooghly', 'howrah', 'hugli', 'jalpaiguri', 'jhargram',
#        'kalimpong', 'koch bihar', 'kolkata', 'malda', 'maldah',
#        'murshidabad', 'nadia', 'north 24 parganas', 'north dinajpur',
#        'north twenty four parganas', 'paschim bardhaman',
#        'paschim medinipur', 'purba bardhaman', 'purba medinipur',
#        'purulia', 'puruliya', 'south 24 parganas',
#        'south twenty four parganas', 'uttar dinajpur', 'west midnapore',
#        'munger', 'muzaffarpur', 'nalanda', 'nawada', 'patna',
#        'purba champaran', 'purnea', 'purnia', 'rohtas', 'saharsa',
#        'samastipur', 'samstipur', 'saran', 'sheikhpura', 'sheohar',
#        'sitamarhi', 'siwan', 'supaul', 'vaishali', 'west champaran',
#        'chandigarh', 'baloda bazar', 'balrampur', 'bastar', 'bemetara',
#        'dakshin bastar dantewada', 'dantewada', 'dhamtari', 'durg',
#        'gariyaband', 'gaurela-pendra-marwahi', 'janjgir-champa',
#        'jashpur', 'kabeerdham', 'kanker', 'kawardha', 'kondagaon',
#        'korba', 'koriya', 'mohalla-manpur-ambagarh chowki', 'mungeli',
#        'raigarh', 'raipur', 'rajnandgaon', 'sarangarh-bilaigarh', 'sukma',
#        'surajpur', 'surguja', 'uttar bastar kanker',
#        'dadra & nagar haveli', 'dadra and nagar haveli', 'diu', 'daman',
#        'central delhi', 'east delhi', 'new delhi', 'north delhi',
#        'north east delhi', 'north west delhi', 'shahdara', 'south delhi',
#        'south west delhi', 'west delhi', 'north goa', 'south goa',
#        'ahmadabad', 'ahmedabad', 'amreli', 'anand', 'arvalli',
#        'banaskantha', 'bharuch', 'bhavnagar', 'botad', 'chhotaudepur',
#        'dahod', 'devbhumi dwarka', 'gandhinagar', 'gir somnath',
#        'jamnagar', 'junagadh', 'kachchh', 'kheda', 'mahesana',
#        'mahisagar', 'morbi', 'narmada', 'navsari', 'panchmahals', 'patan',
#        'porbandar', 'rajkot', 'sabar kantha', 'sabarkantha', 'surat',
#        'surendra nagar', 'surendranagar', 'tapi', 'vadodara', 'valsad',
#        'ambala', 'bhiwani', 'charkhi dadri', 'faridabad', 'fatehabad',
#        'gurgaon', 'hisar', 'jhajjar', 'jind', 'kaithal', 'karnal',
#        'kurukshetra', 'mahendragarh', 'mewat', 'palwal', 'panchkula',
#        'panipat', 'rewari', 'rohtak', 'sirsa', 'sonipat', 'ganderbal',
#        'kulgam', 'pulwama', 'ramban', 'latehar', 'pakaur', 'sahibganj',
#        'chamrajnagar', 'chikmagalur', 'ratnagiri', 'sangli', 'satara',
#        'sindhudurg', 'solapur', 'thane', 'wardha', 'washim', 'washim *',
#        'yavatmal', 'chandel', 'churachandpur', 'imphal west', 'jiribam',
#        'kakching', 'senapati', 'thoubal', 'ukhrul', 'east garo hills',
#        'east khasi hills', 'south west garo hills', 'west garo hills',
#        'west jaintia hills', 'aizawl', 'champhai', 'kolasib', 'lunglei',
#        'mamit', 'mammit', 'serchhip', 'chumukedima', 'dimapur', 'kohima',
#        'longleng', 'mokokchung', 'mon', 'phek', 'zunheboto', 'angul',
#        'anugul', 'balangir', 'baleshwar', 'baleswar', 'bargarh', 'baudh',
#        'bhadrak', 'boudh', 'cuttack', 'debagarh', 'dhenkanal', 'gajapati',
#        'ganjam', 'jajpur', 'jagatsinghapur', 'jagatsinghpur', 'jajapur',
#        'jharsuguda', 'kalahandi', 'kandhamal', 'kendrapara', 'kendujhar',
#        'khorda', 'khordha', 'koraput', 'malkangiri', 'mayurbhanj',
#        'nabarangapur', 'nayagarh', 'nuapada', 'puri', 'rayagada',
#        'sambalpur', 'sonapur', 'subarnapur', 'sundargarh', 'sundergarh',
#        'pondicherry', 'karaikal', 'puducherry', 'amritsar', 'bathinda',
#        'faridkot', 'fatehgarh sahib', 'fazilka', 'ferozepur', 'firozpur',
#        'gurdaspur', 'hoshiarpur', 'jalandhar', 'kapurthala', 'ludhiana',
#        'malerkotla', 'mansa', 'moga', 'muktsar', 'nawanshahr',
#        'pathankot', 'patiala', 'rupnagar', 's.a.s nagar(mohali)',
#        'sas nagar (mohali)', 'sangrur', 'shaheed bhagat singh nagar',
#        'sri muktsar sahib', 'tarn taran', 'ajmer', 'alwar', 'banswara',
#        'baran', 'barmer', 'bharatpur', 'bhilwara', 'bikaner', 'bundi',
#        'chittaurgarh', 'chittorgarh', 'churu', 'dausa', 'deeg', 'dholpur',
#        'dungarpur', 'ganganagar', 'hanumangarh', 'jaipur', 'jaisalmer',
#        'jalor', 'jhalawar', 'jhunjhunun', 'jodhpur', 'karauli', 'kota',
#        'nagaur', 'pali', 'rajsamand', 'sawai madhopur', 'sikar', 'sirohi',
#        'tonk', 'udaipur', 'east', 'east sikkim', 'north sikkim',
#        'south sikkim', 'ariyalur', 'chengalpattu', 'chennai',
#        'coimbatore', 'cuddalore', 'dharmapuri', 'dindigul', 'erode',
#        'kallakurichi', 'kancheepuram', 'kanniyakumari', 'kanyakumari',
#        'karur', 'krishnagiri', 'madurai', 'mayiladuthurai',
#        'nagapattinam', 'namakkal', 'perambalur', 'pudukkottai',
#        'ramanathapuram', 'ranipet', 'salem', 'sivaganga', 'tenkasi',
#        'thanjavur', 'the nilgiris', 'theni', 'thiruvallur', 'thiruvarur',
#        'thoothukkudi', 'tiruchirappalli', 'tirunelveli', 'tirupathur',
#        'tirupattur', 'tiruppur', 'tiruvallur', 'tiruvannamalai',
#        'vellore', 'villupuram', 'viluppuram', 'virudhunagar',
#        'bhadradri kothagudem', 'hanumakonda', 'jagitial', 'jangoan',
#        'jayashankar bhupalpally', 'jogulamba gadwal', 'kamareddy',
#        'komaram bheem', 'mahabubabad', 'mahabubnagar', 'mancherial',
#        'medchal-malkajgiri', 'medchal−malkajgiri', 'mulugu',
#        'nagarkurnool', 'narayanpet', 'nirmal', 'peddapalli',
#        'rajanna sircilla', 'sangareddy', 'siddipet', 'suryapet',
#        'vikarabad', 'wanaparthy', 'warangal rural', 'warangal urban',
#        'yadadri.', 'dhalai', 'gomati', 'north tripura', 'sepahijala',
#        'south tripura', 'west tripura', 'agra', 'aligarh', 'allahabad',
#        'ambedkar nagar', 'amethi', 'amroha', 'auraiya', 'ayodhya',
#        'azamgarh', 'bahraich', 'ballia', 'banda', 'bara banki',
#        'barabanki', 'bareilly', 'basti', 'bhadohi', 'bijnor', 'budaun',
#        'bulandshahr', 'chandauli', 'chitrakoot', 'deoria', 'etah',
#        'etawah', 'faizabad', 'farrukhabad', 'fatehpur', 'firozabad',
#        'gautam buddha nagar', 'ghaziabad', 'ghazipur', 'gonda',
#        'gorakhpur', 'hapur', 'hardoi', 'hathras', 'jalaun', 'jaunpur',
#        'jhansi', 'kannauj', 'kanpur dehat', 'kanpur nagar', 'kasganj',
#        'kaushambi', 'kheri', 'kushinagar', 'lalitpur', 'lucknow',
#        'maharajganj', 'mahoba', 'mainpuri', 'mathura', 'mau', 'meerut',
#        'mirzapur', 'moradabad', 'muzaffarnagar', 'pilibhit', 'haveri *',
#        'alirajpur', 'harda', 'harda *', 'morena', 'narmadapuram',
#        'pandhurna', 'singrauli', 'gondiya', 'hingoli *', 'nanded',
#        'nandurbar', 'nandurbar *', 'nashik', 'osmanabad', 'palghar',
#        'parbhani', 'pune', 'raigad', 'raigarh(mh)', 'nicobar',
#        'k.v.rangareddy', 'dibang valley', 'lower siang', 'tawang',
#        'tirap', 'marigaon', 'araria', 'khagaria', 'shrawasti',
#        'south dinajpur', 'lower dibang valley', 'upper subansiri',
#        'north cachar hills', 'south salmara mankachar', 'aurangabad(bh)',
#        'pashchim champaran', 'balod', 'mahasamund',
#        'manendragarh–chirmiri–bharatpur', 'mohla-manpur-ambagarh chouki',
#        'najafgarh', 'dohad', 'panch mahals', 'the dangs', 'bandipur',
#        'garhwa *', 'bishnupur', 'tamenglong', 'east jaintia hills',
#        'ri bhoi', 'south west khasi hills', 'west khasi hills',
#        'lawngtlai', 'meluri', 'peren', 'shamator', 'tuensang', 'barnala',
#        'jhunjhunu', 'south', 'west', 'west sikkim', 'kanchipuram',
#        'rangareddy', 'khowai', 'unakoti', 'baghpat',
#        'khairagarh chhuikhadan gandai', 'narayanpur', 'sakti', 'palamau',
#        'bagalkot *', 'yanam', 'north', 'sheopur',
#        'chatrapati sambhaji nagar', 'imphal east', 'north garo hills',
#        'kiphire', 'wokha', 'jangaon', 'garhwal', 'uttarkashi',
#        'kurung kumey', 'lower subansiri', 'siang', 'north east',
#        'banas kantha', 'bulandshahar', 'saiha', 'noklak', 'leparada',
#        'mohali', 'dhaulpur', 'chamarajanagar *', 'south garo hills',
#        'shi-yomi', 'janjgir champa', 'jyotiba phule nagar', 'medinipur',
#        'anjaw', 'janjgir - champa', 'dhalai *', 'hnahthial',
#        'sant ravidas nagar bhadohi', 'domjur', 'dima hasao', 'raebareli',
#        'niuland', 'bhabua', 'sheikpura', 'kushinagar *', 'auraiya *',
#        'tamulpur district', 'warangal (urban)', 'monghyr',
#        'south east delhi', 'pakke kessang', 'bardez', 'bengaluru rural',
#        'lahaul and spiti', 'mahrajganj', 'hawrah', 'saitual',
#        'eastern west khasi hills', 'jaintia hills', 'bijapur(kar)',
#        'bally jagachha', 'hooghiy', '?', 'tseminyu', 'didwana-kuchaman',
#        'rajauri', 'tiswadi', 'jalore', 'anugal', 'east midnapur',
#        'khairthal-tijara', 'south dumdum(m)', 'bokaro *',
#        'kotputli-behror', 'beawar', 'tiruvarur', 'nicobars', 'balotra',
#        'namchi', 'bajali', 'bagpat', 'khordha *', 'tuticorin',
#        'leh (ladakh)'], dtype=object)

# %%
df.shape
# Out:
# (469415, 6)

# %%
import pandas as pd
import json

# Step 1: Load your reference JSON file
with open('/content/state_district_reference.json', 'r', encoding='utf-8') as f:
    reference_data = json.load(f)


# Step 3: Create a simple validation function
def is_valid_district(state, district):
    """
    Check if district exists in the given state's district list

    Args:
        state (str): State name (must match JSON key exactly)
        district (str): District name to validate

    Returns:
        bool: True if district is in that state's list, False otherwise
    """
    # Get the districts list for this state from JSON
    if state in reference_data:
        valid_districts = reference_data[state]['districts']
        # Check if district is in the list
        return district in valid_districts
    return False

# Step 4: Apply validation to each row
df['is_valid'] = df.apply(
    lambda row: is_valid_district(row['state'], row['district']),
    axis=1
)

# Step 5: Get rows where matching didn't happen (invalid rows)
invalid_rows = df[df['is_valid'] == False]

# Step 6: Display results
print("=" * 70)
print("DISTRICT VALIDATION REPORT")
print("=" * 70)
print(f"\nTotal rows in dataset: {len(df)}")
print(f"Valid matches (district found in state's list): {df['is_valid'].sum()}")
print(f"INVALID/MISSPELLED rows (matching didn't happen): {len(invalid_rows)}")
print(f"Percentage of invalid rows: {(len(invalid_rows)/len(df)*100):.2f}%")
print("=" * 70)

# Step 7: Show sample of invalid records
if len(invalid_rows) > 0:
    print("\nSample of INVALID records (first 10):")
    print(invalid_rows[['state', 'district']].head(10).to_string(index=False))

    # Breakdown by state
    print("\n\nINVALID records breakdown by STATE:")
    print(invalid_rows['state'].value_counts().to_string())

# Step 8: Decide whether to drop based on count
print("\n" + "=" * 70)
if len(invalid_rows) >= 2000 and len(invalid_rows) <= 3000:
    print(f"✓ Invalid rows count: {len(invalid_rows)} (within 2k-3k range - SAFE TO DROP)")

    # Drop invalid rows and create cleaned dataset
    df_cleaned = df[df['is_valid'] == True].drop('is_valid', axis=1).reset_index(drop=True)

    print(f"✓ Original dataset shape: {df.shape}")
    print(f"✓ Cleaned dataset shape: {df_cleaned.shape}")
    print(f"✓ Rows dropped: {len(df) - len(df_cleaned)}")

    # Save cleaned data
    df_cleaned.to_csv('your_dataset_cleaned.csv', index=False)
    print(f"\n✓ Cleaned dataset saved to 'your_dataset_cleaned.csv'")

elif len(invalid_rows) < 2000:
    print(f"⚠ Invalid rows count: {len(invalid_rows)} (less than 2000)")
    print("  Suggestion: Consider fixing these records instead of dropping")

elif len(invalid_rows) > 3000:
    print(f"✗ Invalid rows count: {len(invalid_rows)} (more than 3000)")
    print("  Suggestion: Data quality issue - manual review needed before dropping")

# Step 9: Export invalid records for reference
if len(invalid_rows) > 0:
    invalid_rows[['state', 'district']].to_csv('invalid_records.csv', index=False)
    print(f"✓ Invalid records exported to 'invalid_records.csv' for review")

print("=" * 70)
# Out:
# ======================================================================
# DISTRICT VALIDATION REPORT
# ======================================================================
#
# Total rows in dataset: 469415
# Valid matches (district found in state's list): 374211
# INVALID/MISSPELLED rows (matching didn't happen): 95204
# Percentage of invalid rows: 20.28%
# ======================================================================
#
# Sample of INVALID records (first 10):
#             state        district
#           haryana    yamuna nagar
#  himachal pradesh   lahul & spiti
#  himachal pradesh lahul and spiti
# jammu and kashmir          badgam
# jammu and kashmir          badgam
# jammu and kashmir       bandipore
# jammu and kashmir        baramula
# jammu and kashmir          kargil
# jammu and kashmir             leh
# jammu and kashmir           punch
#
#
# INVALID records breakdown by STATE:
# state
# andhra pradesh                              16836
# karnataka                                   16248
# west bengal                                  9691
# maharashtra                                  7414
# odisha                                       7244
# tamil nadu                                   4750
# telangana                                    3706
# gujarat                                      3528
# uttar pradesh                                2598
# madhya pradesh                               2247
# punjab                                       2219
# tripura                                      2115
# delhi                                        2082
# manipur                                      1672
# rajasthan                                    1591
# chhattisgarh                                 1475
# bihar                                        1464
# jharkhand                                    1426
# meghalaya                                    1054
# assam                                        1049
# nagaland                                      999
# haryana                                       943
# jammu and kashmir                             903
# sikkim                                        628
# puducherry                                    479
# kerala                                        247
# uttarakhand                                   187
# himachal pradesh                              178
# andaman and nicobar islands                    91
# mizoram                                        82
# dadra and nagar haveli and daman and diu       22
# arunachal pradesh                              18
# goa                                            11
# chandigarh                                      7
#
# ======================================================================
# ✗ Invalid rows count: 95204 (more than 3000)
#   Suggestion: Data quality issue - manual review needed before dropping
# ✓ Invalid records exported to 'invalid_records.csv' for review
# ======================================================================

# %%
df.head()
# Out:
#          date             state      district  pincode  bio_age_5_17  \
# 0  07-11-2025           haryana  yamuna nagar   135002             4
# 1  07-11-2025           haryana   yamunanagar   135001             1
# 2  07-11-2025  himachal pradesh      bilaspur   174004             2
# 3  07-11-2025  himachal pradesh      bilaspur   174005             1
# 4  07-11-2025  himachal pradesh      bilaspur   174013             3
#
#    bio_age_17_  is_valid
# 0            6     False
# 1            2      True
# 2            2      True
# 3            0      True
# 4            1      True

# %%
df_cleaned = df[df['is_valid'] == True].drop('is_valid', axis=1).reset_index(drop=True)

# %%
df_anomalies = df[df['is_valid'] == False].drop('is_valid', axis=1).reset_index(drop=True)

# %%
df_cleaned.shape
# Out:
# (374211, 6)

# %%
df_cleaned.columns
# Out:
# Index(['date', 'state', 'district', 'pincode', 'bio_age_5_17', 'bio_age_17_'], dtype='object')

# %%
df_cleaned.to_csv("cleaned_3")

# %%
df_anomalies.shape
# Out:
# (95204, 6)

# %%
df_anomalies.to_csv('bio_anomalies_3.csv')
