# %%
import pandas as pd

# %%
df = pd.read_csv('/content/bio_anomalies_final.csv')

# %%
df.shape
# Out:
# (359359, 7)

# %%
df.head()
# Out:
#    Unnamed: 0        date              state                    district  \
# 0           0  01-03-2025  jammu and kashmir                       punch
# 1           1  01-03-2025            gujarat                 sabarkantha
# 2           2  01-03-2025             odisha                nabarangapur
# 3           3  01-03-2025             punjab  shaheed bhagat singh nagar
# 4           4  01-03-2025          karnataka                   davangere
#
#    pincode  bio_age_5_17  bio_age_17_
# 0   185101           643         1091
# 1   383440            56           91
# 2   764075           438          605
# 3   144514           134          249
# 4   577002           219          386

# %%
df['state'].unique()
# Out:
# array(['jammu and kashmir', 'gujarat', 'odisha', 'punjab', 'karnataka',
#        'andhra pradesh', 'madhya pradesh', 'nagaland', 'assam',
#        'west bengal', 'delhi', 'maharashtra', 'tamil nadu',
#        'chhattisgarh', 'telangana', 'uttar pradesh', 'meghalaya',
#        'rajasthan', 'haryana', 'bihar', 'puducherry', 'manipur', 'sikkim',
#        'jharkhand', 'tripura', 'mizoram', 'arunachal pradesh',
#        'andaman and nicobar islands', 'kerala',
#        'dadra and nagar haveli and daman and diu', 'himachal pradesh',
#        'uttarakhand', 'goa', 'chandigarh', 'tamilnadu'], dtype=object)

# %%
pip install rapidfuzz
# Out:
# Requirement already satisfied: rapidfuzz in /usr/local/lib/python3.12/dist-packages (3.14.3)

# %%
import json
import numpy as np
from rapidfuzz import process, fuzz

# 1. Load state-district JSON
with open("/content/state_district_reference.json", "r", encoding="utf-8") as f:
    state_district_map = json.load(f)  # :contentReference[oaicite:0]{index=0}

# normalize JSON keys (safety)
state_district_map = {
    k.strip().lower(): [d.strip().lower() for d in v["districts"]]
    for k, v in state_district_map.items()
}

# 2. Normalise df columns
df["state_norm"] = df["state"].str.strip().str.lower()
df["district_norm"] = df["district"].str.strip().str.lower()

# 3. Fuzzy matching function
def match_district(row, threshold=80):
    state = row["state_norm"]
    district = row["district_norm"]

    # state not found in JSON
    if state not in state_district_map or pd.isna(district):
        return np.nan

    district_list = state_district_map[state]

    match = process.extractOne(
        district,
        district_list,
        scorer=fuzz.token_sort_ratio
    )

    if match and match[1] >= threshold:
        return match[0]   # best matched district name
    else:
        return np.nan

# 4. Apply to dataframe
df["district_new"] = df.apply(match_district, axis=1)

# (optional) drop helper columns
df.drop(columns=["state_norm", "district_norm"], inplace=True)

# %%
df.head()
# Out:
#    Unnamed: 0        date              state                    district  \
# 0           0  01-03-2025  jammu and kashmir                       punch
# 1           1  01-03-2025            gujarat                 sabarkantha
# 2           2  01-03-2025             odisha                nabarangapur
# 3           3  01-03-2025             punjab  shaheed bhagat singh nagar
# 4           4  01-03-2025          karnataka                   davangere
#
#    pincode  bio_age_5_17  bio_age_17_               district_new
# 0   185101           643         1091                        NaN
# 1   383440            56           91                        NaN
# 2   764075           438          605                nabarangpur
# 3   144514           134          249  shahid bhagat singh nagar
# 4   577002           219          386                 davanagere

# %%
df[~df['district_new'].isna()].shape
# Out:
# (116070, 8)

# %%
df[~df['district_new'].isna()]['district_new'].unique()
# Out:
# array(['nabarangpur', 'shahid bhagat singh nagar', 'davanagere',
#        'sundargarh', 'ananthapuramu', 'harda', 'tumakuru',
#        'south salmara mancachar', 'banas kantha', 'khordha', 'jajpur',
#        'malda', 'viluppuram', 'thiruvallur', 'tirupathur', 'firozabad',
#        'jhunjhunu', 'bagalkote', 'jalore', 'sonepur', 'kanniyakumari',
#        'budgam', 'gondia', 'chamarajanagar', 'baramulla', 'shivamogga',
#        'hassan', 'boudh', 'agar-malwa', 'chikkamagaluru', 'ranga reddy',
#        'ferozepur', 'dr. b.r. ambedkar konaseema', 'buldhana', 'keonjhar',
#        'purnia', 'pakur', 'ahmedabad', 'purulia', 'angul', 'mamit',
#        'jagatsinghapur', 'sahebganj', 'ashoknagar', 'haveri', 'gadag',
#        'darjeeling', 'narsimhapur', 'mahrajganj', 'bandipora', 'shopian',
#        'jayashankar bhupalapally', 'shi yomi', 'bengaluru rural',
#        'garhwa', 'chikkaballapura', 'hazaribagh', 'sivasagar',
#        'kasaragod', 'bargarh', 'chittorgarh', 'koderma', 'palamu',
#        'siaha', 'dadra and nagar haveli',
#        'manendragarh-chirmiri-bharatpur (m c b)', 'mumbai suburban',
#        'lahaul and spiti', 'kushinagar', 'dholpur', 'aurangabad',
#        'samastipur', 'haridwar', 'nandurbar', 'sheikhpura', 'howrah',
#        'jangoan', 'washim', 'purbi champaran', 'south 24 parganas',
#        'hooghly', 'bulandshahr', 'nicobar', 'baghpat', 'udupi', 'mahoba',
#        'mohla-manpur-ambagarh chouki', 'rajouri', 'hingoli', 'bokaro',
#        'gautam buddha nagar', 'kancheepuram', 'auraiya', 'thiruvarur',
#        'chandauli'], dtype=object)

# %%
df_final = df[~df['district_new'].isna()]

# %%
df_final.head()
# Out:
#    Unnamed: 0        date           state                    district  \
# 2           2  01-03-2025          odisha                nabarangapur
# 3           3  01-03-2025          punjab  shaheed bhagat singh nagar
# 4           4  01-03-2025       karnataka                   davangere
# 5           5  01-03-2025          odisha                  sundergarh
# 7           7  01-03-2025  andhra pradesh                   anantapur
#
#    pincode  bio_age_5_17  bio_age_17_               district_new
# 2   764075           438          605                nabarangpur
# 3   144514           134          249  shahid bhagat singh nagar
# 4   577002           219          386                 davanagere
# 5   769004           152          186                 sundargarh
# 7   515301            83          105              ananthapuramu

# %%
df_final.drop(['district'],axis=1, inplace=True)
# Out:
# /tmp/ipython-input-2705329089.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final.drop(['district'],axis=1, inplace=True)

# %%
df_final.head()
# Out:
#    Unnamed: 0        date           state  pincode  bio_age_5_17  bio_age_17_  \
# 2           2  01-03-2025          odisha   764075           438          605
# 3           3  01-03-2025          punjab   144514           134          249
# 4           4  01-03-2025       karnataka   577002           219          386
# 5           5  01-03-2025          odisha   769004           152          186
# 7           7  01-03-2025  andhra pradesh   515301            83          105
#
#                 district_new
# 2                nabarangpur
# 3  shahid bhagat singh nagar
# 4                 davanagere
# 5                 sundargarh
# 7              ananthapuramu

# %%
df_final.shape
# Out:
# (116070, 7)

# %%
# 1. Rename the column
df_final = df_final.rename(columns={"district_new": "district"})

# 2. Reorder columns
cols = list(df_final.columns)

# Remove district from current position
cols.remove("district")

# Find index of state
state_index = cols.index("state")

# Insert district right after state
cols.insert(state_index + 1, "district")

# Apply new order
df_final = df_final[cols]

# %%
df_final.head()
# Out:
#    Unnamed: 0        date           state                   district  pincode  \
# 2           2  01-03-2025          odisha                nabarangpur   764075
# 3           3  01-03-2025          punjab  shahid bhagat singh nagar   144514
# 4           4  01-03-2025       karnataka                 davanagere   577002
# 5           5  01-03-2025          odisha                 sundargarh   769004
# 7           7  01-03-2025  andhra pradesh              ananthapuramu   515301
#
#    bio_age_5_17  bio_age_17_
# 2           438          605
# 3           134          249
# 4           219          386
# 5           152          186
# 7            83          105

# %%
df_final['district'].isna().sum()
# Out:
# np.int64(0)

# %%
df_final.drop(['Unnamed: 0'],axis=1, inplace=True)

# %%
df_final.head()
# Out:
#          date           state                   district  pincode  \
# 2  01-03-2025          odisha                nabarangpur   764075
# 3  01-03-2025          punjab  shahid bhagat singh nagar   144514
# 4  01-03-2025       karnataka                 davanagere   577002
# 5  01-03-2025          odisha                 sundargarh   769004
# 7  01-03-2025  andhra pradesh              ananthapuramu   515301
#
#    bio_age_5_17  bio_age_17_
# 2           438          605
# 3           134          249
# 4           219          386
# 5           152          186
# 7            83          105

# %%
df_final.shape
# Out:
# (116070, 6)

# %%
df_final.to_csv('bio_anomalies_cleaned.csv',index=False)

# %%
#now saving False data
df_final_false = df[df['district_new'].isna()]

# %%
df_final_false.head()
# Out:
#     Unnamed: 0        date              state     district  pincode  \
# 0            0  01-03-2025  jammu and kashmir        punch   185101
# 1            1  01-03-2025            gujarat  sabarkantha   383440
# 6            6  01-03-2025     andhra pradesh     warangal   506163
# 9            9  01-03-2025           nagaland   mokokchung   798613
# 12          12  01-03-2025  jammu and kashmir          leh   194401
#
#     bio_age_5_17  bio_age_17_ district_new
# 0            643         1091          NaN
# 1             56           91          NaN
# 6             39           92          NaN
# 9             18           70          NaN
# 12            52           43          NaN

# %%
# Simple check
df_final_false[~df_final_false['district_new'].isna()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, date, state, district, pincode, bio_age_5_17, bio_age_17_, district_new]
# Index: []

# %%
df_final_false.drop(['district_new'],axis=1, inplace=True)
# Out:
# /tmp/ipython-input-996238619.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final_false.drop(['district_new'],axis=1, inplace=True)

# %%
df_final_false.head()
# Out:
#     Unnamed: 0        date              state     district  pincode  \
# 0            0  01-03-2025  jammu and kashmir        punch   185101
# 1            1  01-03-2025            gujarat  sabarkantha   383440
# 6            6  01-03-2025     andhra pradesh     warangal   506163
# 9            9  01-03-2025           nagaland   mokokchung   798613
# 12          12  01-03-2025  jammu and kashmir          leh   194401
#
#     bio_age_5_17  bio_age_17_
# 0            643         1091
# 1             56           91
# 6             39           92
# 9             18           70
# 12            52           43

# %%
df_final_false.shape
# Out:
# (243289, 7)

# %%
df_final_false.drop(['Unnamed: 0'],axis=1, inplace=True)
# Out:
# /tmp/ipython-input-1767919031.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final_false.drop(['Unnamed: 0'],axis=1, inplace=True)

# %%
df_final_false.head()
# Out:
#           date              state     district  pincode  bio_age_5_17  \
# 0   01-03-2025  jammu and kashmir        punch   185101           643
# 1   01-03-2025            gujarat  sabarkantha   383440            56
# 6   01-03-2025     andhra pradesh     warangal   506163            39
# 9   01-03-2025           nagaland   mokokchung   798613            18
# 12  01-03-2025  jammu and kashmir          leh   194401            52
#
#     bio_age_17_
# 0          1091
# 1            91
# 6            92
# 9            70
# 12           43

# %%
df_final_false.to_csv('bio_anomalies_false.csv',index=False)
