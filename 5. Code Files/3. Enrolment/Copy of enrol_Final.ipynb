# %%
import pandas as pd

# %%
df1 = pd.read_csv('/content/enrol_anomalies_1.csv')
df2 = pd.read_csv('/content/enrol_anomalies_2.csv')
df3 = pd.read_csv('/content/enrol_anomalies_3.csv')

# %%
df = pd.concat([df1,df2,df3])

# %%
df.shape
# Out:
# (176844, 8)

# %%
df.drop('Unnamed: 0',axis=1,inplace=True)

# %%
df.shape
# Out:
# (176844, 7)

# %%
df.head()
# Out:
#          date          state          district  pincode  age_0_5  age_5_17  \
# 0  02-03-2025      meghalaya  east khasi hills   793121       11        61
# 1  09-03-2025  uttar pradesh       maharajganj   273164       31        70
# 2  09-03-2025    maharashtra        aurangabad   431001       42        46
# 3  09-03-2025          delhi        west delhi   110018       29        11
# 4  09-03-2025          delhi        west delhi   110059       93        42
#
#    age_18_greater
# 0              37
# 1              13
# 2              12
# 3              15
# 4              42

# %%
df.to_csv('enrol_anomalies_final.csv',index=False)
