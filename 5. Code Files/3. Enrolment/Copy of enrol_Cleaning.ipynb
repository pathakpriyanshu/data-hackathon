# %% [markdown]
# # UIDAI Enrollment Data Analysis file 1

# %%
#importing necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1 = pd.read_csv('/content/api_data_aadhar_enrolment_1000000_1006029.csv')

# %%
df1.head()
# Out:
#          date      state district  pincode  age_0_5  age_5_17  age_18_greater
# 0  31-12-2025  Karnataka    Bidar   585330        2         3               0
# 1  31-12-2025  Karnataka    Bidar   585402        6         0               0
# 2  31-12-2025  Karnataka    Bidar   585413        1         0               0
# 3  31-12-2025  Karnataka    Bidar   585418        1         2               0
# 4  31-12-2025  Karnataka    Bidar   585421        4         3               0

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6029 entries, 0 to 6028
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   date            6029 non-null   object
#  1   state           6029 non-null   object
#  2   district        6029 non-null   object
#  3   pincode         6029 non-null   int64
#  4   age_0_5         6029 non-null   int64
#  5   age_5_17        6029 non-null   int64
#  6   age_18_greater  6029 non-null   int64
# dtypes: int64(4), object(3)
# memory usage: 329.8+ KB

# %%
df1.describe()
# Out:
#              pincode      age_0_5     age_5_17  age_18_greater
# count    6029.000000  6029.000000  6029.000000     6029.000000
# mean   518765.547023     3.606734     3.493448        0.096533
# std    193308.752319     6.055847     6.694502        0.479475
# min    110003.000000     0.000000     0.000000        0.000000
# 25%    380022.000000     1.000000     0.000000        0.000000
# 50%    518005.000000     2.000000     1.000000        0.000000
# 75%    685595.000000     4.000000     3.000000        0.000000
# max    855116.000000   102.000000    89.000000        9.000000

# %%
df1.shape
# Out:
# (6029, 7)

# %%
df1.columns
# Out:
# Index(['date', 'state', 'district', 'pincode', 'age_0_5', 'age_5_17',
#        'age_18_greater'],
#       dtype='object')

# %%
df1.isnull().sum()
# Out:
# date              0
# state             0
# district          0
# pincode           0
# age_0_5           0
# age_5_17          0
# age_18_greater    0
# dtype: int64

# %%
#duplicated data
df1[df1.duplicated()]
# Out:
# Empty DataFrame
# Columns: [date, state, district, pincode, age_0_5, age_5_17, age_18_greater]
# Index: []

# %%
# without duplicates data
df1 = df1[~df1.duplicated()]
df1.shape
# Out:
# (6029, 7)

# %%
# Making copy of data for cleaning
df = df1.copy()

# %%
df[~df.duplicated()]
# Out:
#             date        state        district  pincode  age_0_5  age_5_17  \
# 0     31-12-2025    Karnataka           Bidar   585330        2         3
# 1     31-12-2025    Karnataka           Bidar   585402        6         0
# 2     31-12-2025    Karnataka           Bidar   585413        1         0
# 3     31-12-2025    Karnataka           Bidar   585418        1         2
# 4     31-12-2025    Karnataka           Bidar   585421        4         3
# ...          ...          ...             ...      ...      ...       ...
# 6024  31-12-2025  West Bengal  West Midnapore   721149        2         0
# 6025  31-12-2025  West Bengal  West Midnapore   721150        2         2
# 6026  31-12-2025  West Bengal  West Midnapore   721305        0         1
# 6027  31-12-2025  West Bengal  West Midnapore   721504        1         0
# 6028  31-12-2025  West Bengal  West Midnapore   721517        2         1
#
#       age_18_greater
# 0                  0
# 1                  0
# ...

# %%
# removing duplicates
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (6029, 7)

# %%
df.head()
# Out:
#          date      state district  pincode  age_0_5  age_5_17  age_18_greater
# 0  31-12-2025  Karnataka    Bidar   585330        2         3               0
# 1  31-12-2025  Karnataka    Bidar   585402        6         0               0
# 2  31-12-2025  Karnataka    Bidar   585413        1         0               0
# 3  31-12-2025  Karnataka    Bidar   585418        1         2               0
# 4  31-12-2025  Karnataka    Bidar   585421        4         3               0

# %%
# First Feature Cleaning
df['state'].unique()
# Out:
# array(['Karnataka', 'Kerala', 'Ladakh', 'Lakshadweep', 'Madhya Pradesh',
#        'Maharashtra', 'Manipur', 'Meghalaya', 'Mizoram', 'Nagaland',
#        'Odisha', 'Orissa', 'Puducherry', 'Punjab', 'Rajasthan', 'Sikkim',
#        'Tamil Nadu', 'Telangana', 'Tripura', 'Uttar Pradesh',
#        'Uttarakhand', 'West Bengal', 'Andhra Pradesh',
#        'Arunachal Pradesh', 'Assam', 'Bihar', 'Chandigarh',
#        'Chhattisgarh', 'Daman and Diu', 'Delhi', 'Goa', 'Gujarat',
#        'Haryana', 'Himachal Pradesh', 'Jammu and Kashmir', 'Jharkhand',
#        'Pondicherry'], dtype=object)

# %%
df['state']=df['state'].str.strip().str.lower()

# %%
df['state'].unique()
# Out:
# array(['karnataka', 'kerala', 'ladakh', 'lakshadweep', 'madhya pradesh',
#        'maharashtra', 'manipur', 'meghalaya', 'mizoram', 'nagaland',
#        'odisha', 'orissa', 'puducherry', 'punjab', 'rajasthan', 'sikkim',
#        'tamil nadu', 'telangana', 'tripura', 'uttar pradesh',
#        'uttarakhand', 'west bengal', 'andhra pradesh',
#        'arunachal pradesh', 'assam', 'bihar', 'chandigarh',
#        'chhattisgarh', 'daman and diu', 'delhi', 'goa', 'gujarat',
#        'haryana', 'himachal pradesh', 'jammu and kashmir', 'jharkhand',
#        'pondicherry'], dtype=object)

# %%
df[df['state'].str.contains("&")]['state'].str.replace("&", "and")
# Out:
# Series([], Name: state, dtype: object)

# %%
df['state']=df['state'].str.replace("&", "and")

# %%
df[df['state'].str.startswith("o")]['state'].unique()
# Out:
# array(['odisha', 'orissa'], dtype=object)

# %%
df['state']=df['state'].str.replace('orissa','odisha')
df['state'] = df['state'].str.replace('chhatisgarh', 'chhattisgarh')
df['state'] = df['state'].str.replace('west bengli', 'west bengal')

# %%
df['state'].unique()
# Out:
# array(['karnataka', 'kerala', 'ladakh', 'lakshadweep', 'madhya pradesh',
#        'maharashtra', 'manipur', 'meghalaya', 'mizoram', 'nagaland',
#        'odisha', 'puducherry', 'punjab', 'rajasthan', 'sikkim',
#        'tamil nadu', 'telangana', 'tripura', 'uttar pradesh',
#        'uttarakhand', 'west bengal', 'andhra pradesh',
#        'arunachal pradesh', 'assam', 'bihar', 'chandigarh',
#        'chhattisgarh', 'daman and diu', 'delhi', 'goa', 'gujarat',
#        'haryana', 'himachal pradesh', 'jammu and kashmir', 'jharkhand',
#        'pondicherry'], dtype=object)

# %%
df['state'] = df['state'].replace({
    'daman and diu': 'dadra and nagar haveli and daman and diu',
    'dadra and nagar haveli': 'dadra and nagar haveli and daman and diu',

})

# %%
df['state']=df['state'].str.replace(
    r'^\s*west\s*b[aeo]ngal\s*$',
    'west bengal',
    regex=True
)

# %%
df['state']=df['state'].replace({'pondicherry':'puducherry', 'uttaranchal':'uttarakhand'})

# %%
df[df['state']=='darbhanga']
# Out:
# Empty DataFrame
# Columns: [date, state, district, pincode, age_0_5, age_5_17, age_18_greater]
# Index: []

# %%
df[df['state']=='puttenahalli']
# Out:
# Empty DataFrame
# Columns: [date, state, district, pincode, age_0_5, age_5_17, age_18_greater]
# Index: []

# %%
df['state'].unique()
# Out:
# array(['karnataka', 'kerala', 'ladakh', 'lakshadweep', 'madhya pradesh',
#        'maharashtra', 'manipur', 'meghalaya', 'mizoram', 'nagaland',
#        'odisha', 'puducherry', 'punjab', 'rajasthan', 'sikkim',
#        'tamil nadu', 'telangana', 'tripura', 'uttar pradesh',
#        'uttarakhand', 'west bengal', 'andhra pradesh',
#        'arunachal pradesh', 'assam', 'bihar', 'chandigarh',
#        'chhattisgarh', 'dadra and nagar haveli and daman and diu',
#        'delhi', 'goa', 'gujarat', 'haryana', 'himachal pradesh',
#        'jammu and kashmir', 'jharkhand'], dtype=object)

# %% [markdown]
# # State Feature Cleaned

# %% [markdown]
# ## Moving to next Feature (District)

# %%
df.shape
# Out:
# (6029, 7)

# %%
df['district'] = (
    df['district']
    .str.lower()
    .str.strip()
    .str.replace(r'\s+', ' ', regex=True)
)

# %%
df['district'].nunique()
# Out:
# 771

# %% [markdown]
# # It has various Unique values, so applying other logic

# %%
df['district'].unique()
# Out:
# array(['bidar', 'bijapur', 'chamrajanagar', 'chamrajnagar',
#        'chickmagalur', 'chikkaballapur', 'chikkamagaluru', 'chikmagalur',
#        'chitradurga', 'dakshina kannada', 'davanagere', 'davangere',
#        'dharwad', 'gadag', 'gadag *', 'gulbarga', 'hasan', 'hassan',
#        'haveri', 'kalaburagi', 'kodagu', 'kolar', 'koppal', 'mandya',
#        'mysore', 'mysuru', 'raichur', 'ramanagar', 'shimoga',
#        'shivamogga', 'tumakuru', 'tumkur', 'udupi', 'uttara kannada',
#        'vijayanagara', 'vijayapura', 'yadgir', 'alappuzha', 'ernakulam',
#        'idukki', 'kannur', 'kasaragod', 'kollam', 'kottayam', 'kozhikode',
#        'malappuram', 'palakkad', 'pathanamthitta', 'thiruvananthapuram',
#        'thrissur', 'wayanad', 'leh', 'lakshadweep', 'agar malwa',
#        'alirajpur', 'anuppur', 'ashok nagar', 'balaghat', 'barwani',
#        'betul', 'bhind', 'bhopal', 'burhanpur', 'chhatarpur',
#        'chhindwara', 'damoh', 'datia', 'dewas', 'dhar', 'east nimar',
# ...

# %%
df.shape
# Out:
# (6029, 7)

# %%
import pandas as pd
import json

# Step 1: Load your reference JSON file
with open('/content/state_district_reference.json', 'r', encoding='utf-8') as f:
    reference_data = json.load(f)


# Step 3: Create a simple validation function
def is_valid_district(state, district):
    """
    Check if district exists in the given state's district list

    Args:
        state (str): State name (must match JSON key exactly)
        district (str): District name to validate

    Returns:
        bool: True if district is in that state's list, False otherwise
    """
    # Get the districts list for this state from JSON
    if state in reference_data:
        valid_districts = reference_data[state]['districts']
        # Check if district is in the list
        return district in valid_districts
    return False

# Step 4: Apply validation to each row
df['is_valid'] = df.apply(
    lambda row: is_valid_district(row['state'], row['district']),
    axis=1
)

# Step 5: Get rows where matching didn't happen (invalid rows)
invalid_rows = df[df['is_valid'] == False]

# Step 6: Display results
print("=" * 70)
print("DISTRICT VALIDATION REPORT")
print("=" * 70)
print(f"\nTotal rows in dataset: {len(df)}")
print(f"Valid matches (district found in state's list): {df['is_valid'].sum()}")
print(f"INVALID/MISSPELLED rows (matching didn't happen): {len(invalid_rows)}")
print(f"Percentage of invalid rows: {(len(invalid_rows)/len(df)*100):.2f}%")
print("=" * 70)

# Step 7: Show sample of invalid records
if len(invalid_rows) > 0:
    print("\nSample of INVALID records (first 10):")
    print(invalid_rows[['state', 'district']].head(10).to_string(index=False))

    # Breakdown by state
    print("\n\nINVALID records breakdown by STATE:")
    print(invalid_rows['state'].value_counts().to_string())

# Step 8: Decide whether to drop based on count
print("\n" + "=" * 70)
if len(invalid_rows) >= 2000 and len(invalid_rows) <= 3000:
    print(f"✓ Invalid rows count: {len(invalid_rows)} (within 2k-3k range - SAFE TO DROP)")

    # Drop invalid rows and create cleaned dataset
    df_cleaned = df[df['is_valid'] == True].drop('is_valid', axis=1).reset_index(drop=True)

    print(f"✓ Original dataset shape: {df.shape}")
    print(f"✓ Cleaned dataset shape: {df_cleaned.shape}")
    print(f"✓ Rows dropped: {len(df) - len(df_cleaned)}")

    # Save cleaned data
    df_cleaned.to_csv('your_dataset_cleaned.csv', index=False)
    print(f"\n✓ Cleaned dataset saved to 'your_dataset_cleaned.csv'")

elif len(invalid_rows) < 2000:
    print(f"⚠ Invalid rows count: {len(invalid_rows)} (less than 2000)")
    print("  Suggestion: Consider fixing these records instead of dropping")

elif len(invalid_rows) > 3000:
    print(f"✗ Invalid rows count: {len(invalid_rows)} (more than 3000)")
    print("  Suggestion: Data quality issue - manual review needed before dropping")

# Step 9: Export invalid records for reference
if len(invalid_rows) > 0:
    invalid_rows[['state', 'district']].to_csv('invalid_records.csv', index=False)
    print(f"✓ Invalid records exported to 'invalid_records.csv' for review")

print("=" * 70)
# Out:
# ...
# DISTRICT VALIDATION REPORT
# ...
#
# Total rows in dataset: 6029
# Valid matches (district found in state's list): 4979
# INVALID/MISSPELLED rows (matching didn't happen): 1050
# Percentage of invalid rows: 17.42%
# ...
#
# Sample of INVALID records (first 10):
#     state      district
# karnataka       bijapur
# karnataka       bijapur
# karnataka       bijapur
# karnataka       bijapur
# karnataka       bijapur
# karnataka       bijapur
# karnataka       bijapur
# karnataka       bijapur
# karnataka chamrajanagar
# karnataka chamrajanagar
#
#
# INVALID records breakdown by STATE:
# state
# karnataka            161
# west bengal          147
# odisha               107
# maharashtra           98
# tamil nadu            76
# andhra pradesh        69
# telangana             59
# madhya pradesh        46
# uttar pradesh         42
# rajasthan             34
# tripura               33
# manipur               26
# meghalaya             25
# gujarat               25
# chhattisgarh          14
# ...

# %%
df.head()
# Out:
#          date      state district  pincode  age_0_5  age_5_17  age_18_greater  \
# 0  31-12-2025  karnataka    bidar   585330        2         3               0
# 1  31-12-2025  karnataka    bidar   585402        6         0               0
# 2  31-12-2025  karnataka    bidar   585413        1         0               0
# 3  31-12-2025  karnataka    bidar   585418        1         2               0
# 4  31-12-2025  karnataka    bidar   585421        4         3               0
#
#    is_valid
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True

# %%
df_cleaned = df[df['is_valid'] == True].drop('is_valid', axis=1).reset_index(drop=True)

# %%
df_anomalies = df[df['is_valid']==False].drop('is_valid',axis=1).reset_index(drop=True)

# %%
df_cleaned.shape
# Out:
# (4979, 7)

# %%
df_cleaned.columns
# Out:
# Index(['date', 'state', 'district', 'pincode', 'age_0_5', 'age_5_17',
#        'age_18_greater'],
#       dtype='object')

# %%
df_cleaned['state'].unique()
# Out:
# array(['karnataka', 'kerala', 'ladakh', 'lakshadweep', 'madhya pradesh',
#        'maharashtra', 'mizoram', 'odisha', 'puducherry', 'punjab',
#        'rajasthan', 'tamil nadu', 'telangana', 'uttar pradesh',
#        'uttarakhand', 'west bengal', 'andhra pradesh',
#        'arunachal pradesh', 'assam', 'bihar', 'chandigarh',
#        'chhattisgarh', 'dadra and nagar haveli and daman and diu',
#        'delhi', 'goa', 'gujarat', 'haryana', 'himachal pradesh',
#        'jammu and kashmir', 'jharkhand'], dtype=object)

# %%
df_cleaned.to_csv("enrol_cleaned_3.csv")

# %%
df_anomalies.shape
# Out:
# (1050, 7)

# %%
df_anomalies.to_csv('enrol_anomalies_3.csv')
